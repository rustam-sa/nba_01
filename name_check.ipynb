# %%
from data_manager import DataManager
dm = DataManager()

# %%
players = dm.query_players()

# %%
for player in players:
    if 'Jonas' in player.name:
        print(player.name)
# Out:
# Jonas Valančiūnas
