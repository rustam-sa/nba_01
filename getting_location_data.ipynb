# %%
from nba_api.stats.endpoints import LeagueDashPlayerShotLocations
from open_excel import open_df_in_temp_excel
import pandas as pd



def aggregate_shot_zones(seasons:list, season_type="Regular Season"):
    # Fetch shot zone data
    shot_zone_dfs = []
    for season in seasons:
        shot_zone_data = LeagueDashPlayerShotLocations(
            season=season,
            season_type_all_star=season_type
        )
        shot_zone_df = shot_zone_data.get_data_frames()[0]
        shot_zone_df.columns = [' '.join(col).strip() if isinstance(col, tuple) else col for col in shot_zone_df.columns]
        shot_zone_dfs.append(shot_zone_df)

    shot_zone_combined = pd.concat(shot_zone_dfs)
    shot_zone_combined = shot_zone_combined.groupby(['PLAYER_NAME'], as_index=False).sum()
    return shot_zone_combined

# %%
# Define parameters
seasons = '2023-24', '2024-25'
season_type = 'Regular Season'
df = aggregate_shot_zones(seasons, season_type)

# %%
display(df.head())
# Out:
#    PLAYER_ID    PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION   AGE NICKNAME  \
# 0    1630639    A.J. Lawson  1610612742               DAL  23.0     A.J.
# 1    1631260       AJ Green  1610612749               MIL  24.0       AJ
# 2    1631100     AJ Griffin  1610612737               ATL  20.0       AJ
# 3     203932   Aaron Gordon  1610612743               DEN  28.0    Aaron
# 4    1628988  Aaron Holiday  1610612745               HOU  27.0    Aaron
#
#    Restricted Area FGM  Restricted Area FGA  Restricted Area FG_PCT  \
# 0                 38.0                 53.0                   0.717
# 1                  6.0                  7.0                   0.857
# 2                  3.0                  5.0                   0.600
# 3                328.0                463.0                   0.708
# 4                 46.0                 71.0                   0.648
#
#    In The Paint (Non-RA) FGM  ...  Right Corner 3 FG_PCT  \
# 0                        1.0  ...                  0.267
# 1                        0.0  ...                  0.400
# 2                        3.0  ...                  0.333
# 3                       19.0  ...                  0.481
# 4                       33.0  ...                  0.516
#
#    Above the Break 3 FGM  Above the Break 3 FGA  Above the Break 3 FG_PCT  \
# 0                    5.0                   18.0                     0.278
# 1                   51.0                  130.0                     0.392
# 2                    8.0                   30.0                     0.267
# 3                   20.0                   81.0                     0.247
# 4                   61.0                  167.0                     0.365
#
#    Backcourt FGM  Backcourt FGA  Backcourt FG_PCT  Corner 3 FGM  Corner 3 FGA  \
# 0            0.0            0.0               0.0           8.0          32.0
# 1            0.0            0.0               0.0          18.0          39.0
# 2            0.0            0.0               0.0           2.0           9.0
# 3            0.0            1.0               0.0          20.0          56.0
# 4            0.0            1.0               0.0          23.0          49.0
#
#    Corner 3 FG_PCT
# 0            0.250
# 1            0.462
# 2            0.222
# 3            0.357
# 4            0.469
#
# [5 rows x 30 columns]

# %%
open_df_in_temp_excel(df_grouped)
# Out:
# Temporary Excel file opened at: C:\Users\rusta\AppData\Local\Temp\tmp0knwo8nw.xlsx
