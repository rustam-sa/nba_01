# %%
import requests
from dotenv import load_dotenv

url = "https://data.oddsblaze.com/v1/odds/betrivers_nfl.json"
api_key = "OBFf1kMTMqJ3I8AFwWKXb2E"

params = {
    "key": api_key
}

try:
    response = requests.get(url, params=params)
    response.raise_for_status()
    print("Response Status Code:", response.status_code)
    print("Response Data:", response.json())  # Use .text if you expect non-JSON data
except requests.exceptions.RequestException as e:
    print("Error:", e)
    if e.response:
        print("Response Content:", e.response.content)
# Out:
# Response Status Code: 200
# Response Data: {'games': [{'id': 'nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'sport': 'Football', 'league': 'NFL', 'teams': {'away': {'id': 'nfl:green_bay_packers', 'name': 'Green Bay Packers', 'abbreviation': 'GB'}, 'home': {'id': 'nfl:detroit_lions', 'name': 'Detroit Lions', 'abbreviation': 'DET'}}, 'start': '2024-12-06T01:15:00', 'status': 'Scheduled', 'live': False, 'tournament': 'Regular Season Week 14', 'sportsbooks': [{'id': 'betrivers', 'name': 'BetRivers', 'odds': [{'id': 'betrivers:1st_half_moneyline:detroit_lions:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'group': 'betrivers:1st_half_moneyline:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'market': '1st Half Moneyline', 'name': 'Detroit Lions', 'main': True, 'price': '-165', 'points': None, 'selection': 'Home', 'link': 'https://{state}.betrivers.com/?page=sportsbook#event/1020832302?coupon=straight|3582984675|{amount}', 'sgp': None, 'grade': 'eXY5K3J6ZW4yMVl2c09qcElkZWhpbkw0TTF4L29mWkthSitEcTBYTlpXSWdBNWxYbVhlZDBVREgxZTRtamNMbWo0ZDc3a0xubzB4YTdRcklWZStLVWRIQ0lId0pHQTRHeDN0RWVoNXdRckhJcWZ3Z1VjYTBQeWYwY0RoN3lJVEd5YnFJQ094Rkt3RWlZYmpuOXh5REhzbUZNSmcxWlhvWndQbENkMWJnTWhnPQ==', 'players': [], 'updated': '2024-12-04T04:04:10'}, {'id': 'betrivers:1st_half_moneyline:green_bay_packers:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'group': 'betrivers:1st_half_moneyline:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'market': '1st Half Moneyline', 'name': 'Green Bay Packers', 'main': True, 'price': '+132', 'points': None, 'selection': 'Away', 'link': 'https://{state}.betrivers.com/?page=sportsbook#event/1020832302?coupon=straight|3582984678|{amount}', 'sgp': None, 'grade': '', 'players': [], 'updated': '2024-12-04T04:04:10'}, {'id': 'betrivers:1st_half_point_spread:detroit_lions_-2.5:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'group': 'betrivers:1st_half_point_spread:-2.5:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'market': '1st Half Point Spread', 'name': 'Detroit Lions -2.5', 'main': True, 'price': '-114', 'points': -2.5, 'selection': 'Home', 'link': 'https://{state}.betrivers.com/?page=sportsbook#event/1020832302?coupon=straight|3582984577|{amount}', 'sgp': 'MU1QcitjdVRaZjZKQXFBYWRhdVdTa0hvczRPcExPTE45VW9KNnZGNktBUT0=', 'grade': '', 'players': [], 'updated': '2024-12-04T04:04:10'}, {'id': 'betrivers:1st_half_point_spread:green_bay_packers_+2.5:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'group': 'betrivers:1st_half_point_spread:-2.5:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'market': '1st Half Point Spread', 'name': 'Green Bay Packers +2.5', 'main': True, 'price': '-109', 'points': 2.5, 'selection': 'Away', 'link': 'https://{state}.betrivers.com/?page=sportsbook#event/1020832302?coupon=straight|3582984579|{amount}', 'sgp': 'MU1QcitjdVRaZjZKQXFBYWRhdVdTbmdudFREUG1jY245VnhKeStqdnV4bz0=', 'grade': '', 'players': [], 'updated': '2024-12-04T04:04:10'}, {'id': 'betrivers:1st_half_total_points:over_25.5:nfl:green_bay_packers:detroit_lions:2024-regular-season-week-14', 'group': 'betrivers:1st_half_total_points:25.5:nfl:green_bay_packer ...
