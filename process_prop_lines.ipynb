# %%
import pandas as pd
import itertools
from datetime import date
from data_manager import DataManager
import analyze
from models import Player

dm = DataManager()

class Prop:
    def __init__(self, name, team, stat, threshold, odds, bet_type):
        self.name = name
        self.team = team
        self.stat = stat
        self.n = threshold
        self.odds = odds
        self.bet_type = bet_type
        self.probability = self.get_prop_probability()
        self.ev, self.house_prob = self.get_ev_and_implied_prob()
        self.print_out = f"""
            PLAYER: {self.name}
              STAT: {self.stat}
            THRESH: {self.n}
              ODDS: {self.odds}
              TYPE: {self.bet_type}
              PROB: {self.probability}
                EV: {self.ev}
        HOUSE_PROB: {self.house_prob}
            """
        print(self.print_out)
        self.entry = {
            "PLAYER": self.name,
              "TEAM": self.team,
              "STAT": self.stat,
            "THRESH": self.n,
              "ODDS": self.odds,
              "TYPE": self.bet_type,
              "PROB": self.probability,
                "EV": self.ev,
        "HOUSE_PROB": self.house_prob
        }
    
    def get_prop_probability(self, last_n_games=25):
        player_id = dm.get_player_id(self.name)
        data = dm.get_and_save_player_data(player_id, self.name).sort_values(by='date', ascending=False).head(last_n_games).copy()
        # print(data.head())
        if self.bet_type == "over":
            return analyze.estimate_probability_poisson_over(data, self.stat, self.n)
        elif self.bet_type == "under":
            return analyze.estimate_probability_poisson_under(data, self.stat, self.n)
        else:
            raise ValueError("Invalid bet type. Use 'over' or 'under'.")
        
    def get_ev_and_implied_prob(self):
        odds = self.american_to_decimal(self.odds)
        house_probability = analyze.estimate_implied_probability(odds)
        ev = analyze.calculate_ev(self.probability, odds, 5)
        return ev, house_probability
    
    @staticmethod
    def american_to_decimal(american_odds):
        """Convert American odds to decimal odds."""
        if american_odds > 0:
            return 1 + (american_odds / 100)
        else:
            return 1 + (100 / abs(american_odds))
    

def extract_raw_data(file_path): # .csv
    # gets input from A1
    # Sample input text (use the content of your file here)
    raw_input = pd.read_csv(file_path)
    list_of_raw_input = list(raw_input.iloc[:, 0])
    return list_of_raw_input


def load_available_props():
    
    raw_input = extract_raw_data("prop_lines/prop_lines.csv")
    print("Received raw input.")
    stat_names = {
             'PointsSGP': "points",
            'AssistsSGP': "assists",
        'Threes MadeSGP': "fg3m",
           'ReboundsSGP': "rebounds",
   'Field Goals MadeSGP': "fgm",
             'StealsSGP': "steals",
             'BlocksSGP': "blocks",
        }
    #debug stat_name_inputs = extract_raw_data("prop_lines/player_prop_categories.csv")
    players = dm.query_players()
    player_names = [player.name for player in players]
    teams = dm.query_teams()
    team_names = [team.nickname for team in teams]
    row_of_interest = 0
    current_category = None
    current_player = None
    current_team = None
    records = []
    for _, item in enumerate(raw_input):
        if item in stat_names:
            current_category = stat_names[item]
            print(f"Loading {current_category} props.")
        if item != current_team:
            if item in team_names:
                current_team = item
        if item in player_names:
            current_player = item 
            assert current_team
            record = [current_player, current_team, current_category]
            row_of_interest = 6


        if row_of_interest:
            row_of_interest -= 1
            if row_of_interest < 5:
                record.append(item)
                if row_of_interest == 1:
                    records.append(record)
                    record = []
    df = pd.DataFrame.from_records(records, columns=["player_name", "team", "stat", "over_threshold", "over_odds", "under_threshold", "under_odds"])
    
    df['player_name'] = df['player_name'].astype(str)
    df['team'] = df['team'].astype(str)
    df['stat'] = df['stat'].astype(str)
    df['over_threshold'] = df['over_threshold'].str.extract(r'(\d+\.\d+)').astype(float)
    df['under_threshold'] = df['under_threshold'].str.extract(r'(\d+\.\d+)').astype(float)
    df['over_odds'] = df['over_odds'].astype(int)
    df['under_odds'] = df['under_odds'].astype(int)

    return df


def get_analyzed_props(available_props):
    props = []
    for _, row in available_props.iterrows():
        for bet_type in ["over", "under"]:
            prop = Prop(
                    name=row["player_name"], 
                    team=row["team"],
                    stat=row["stat"], 
                threshold=row[f"{bet_type}_threshold"], 
                    odds=row[f"{bet_type}_odds"], 
                bet_type=bet_type
                )
            props.append(prop)    
            print("Prop object created.")

    return props


def generate_heterogenous_combinations(df, n):

    # Generate all combinations of n rows
    combinations = list(itertools.combinations(df.index, n))

    # Function to evaluate heterogeneity of a combination
    def evaluate_heterogeneity(comb, df):
        comb_list = list(comb)
        players = df.loc[comb_list, 'PLAYER']
        stats = df.loc[comb_list, 'STAT']
        teams = df.loc[comb_list, 'TEAM']
        # Calculate a simple heterogeneity score (you can define your own logic)
        player_score = len(set(players))
        stat_score = len(set(stats))
        team_score = len(set(teams))
        return player_score + stat_score + team_score

    # Evaluate all combinations and sort them by heterogeneity score
    comb_scores = [(comb, evaluate_heterogeneity(comb, df)) for comb in combinations]
    comb_scores_sorted = sorted(comb_scores, key=lambda x: x[1], reverse=True)

    # Select the most heterogeneous combinations (you can define how many you want)
    top_combinations = comb_scores_sorted # Top 5 combinations for example

    # Display the most heterogeneous combinations
    for comb, score in top_combinations:
        print(f"Combination: {comb}, Score: {score}")
        print(df.loc[list(comb)])
        print()

    # Optional: Convert combinations to DataFrame
    top_comb_dfs = [(df.loc[list(comb)], score) for comb, score in top_combinations]

    return top_comb_dfs

# %%
available_props = load_available_props()
analyzed_props = get_analyzed_props(available_props)
print(f"num of props: {len(analyzed_props)}")
profitable_props = [prop for prop in analyzed_props if prop.ev > 0]
print(f"num of profitable props: {len(profitable_props)}")
profitable_props_df = pd.DataFrame.from_dict([prop.entry for prop in profitable_props])
# Out:
# Received raw input.
# Loading points props.
# Loading assists props.
# Loading fg3m props.
# Loading rebounds props.
# Loading fgm props.
# Loading steals props.
# Loading blocks props.
#
#             PLAYER: Jalen Brunson
#               STAT: points
#             THRESH: 34.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.44909906446823733
#                 EV: -0.8019000495360427
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: points
#             THRESH: 34.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.5509009355317627
#                 EV: 0.14972613649256417
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: points
#             THRESH: 14.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.32895814554194647
#                 EV: -2.0393766901224817
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: points
#             THRESH: 14.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.6710418544580535
#                 EV: 1.5506466744714746
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: points
#             THRESH: 13.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.44014579235180673
#                 EV: -0.7986083457327533
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: points
#             THRESH: 13.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5598542076481933
#                 EV: 0.13199690344177206
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: points
#             THRESH: 8.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.7497711177188712
#                 EV: 2.4977111771887115
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: points
#             THRESH: 8.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.25022888228112883
#                 EV: -2.786436810590014
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: points
#             THRESH: 16.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.7017479492312456
#                 EV: 1.3157315430812107
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: points
#             THRESH: 16.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.2982520507687544
#                 EV: -2.088491885352636
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: points
#             THRESH: 10.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.09570581498801223
#                 EV: -4.122696695943221
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: points
#             THRESH: 10.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.9042941850119878
#                 EV: 3.6318990387507935
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: points
#             THRESH: 4.5
#               ODDS: -130
#               TYPE: over
#               PROB: 0.580304290724543
#                 EV: 0.13346103333249637
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: points
#             THRESH: 4.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.419695709275457
#                 EV: -0.8030429072454295
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: points
#             THRESH: 17.5
#               ODDS: -105
#               TYPE: over
#               PROB: 0.39369317881834665
#                 EV: -1.1568046829637595
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: points
#             THRESH: 17.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.6063068211816534
#                 EV: 0.3634834181453952
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: points
#             THRESH: 9.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.6594893575343389
#                 EV: 1.2951256855550541
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: points
#             THRESH: 9.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.3405106424656611
#                 EV: -1.8786524440647727
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: points
#             THRESH: 9.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.6463255635236558
#                 EV: 0.924650998966845
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: points
#             THRESH: 9.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.3536744364763442
#                 EV: -1.6240167427258045
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: points
#             THRESH: 10.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.7198291659621494
#                 EV: 1.871096584184154
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: points
#             THRESH: 10.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.28017083403785054
#                 EV: -2.4317673546530365
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: points
#             THRESH: 20.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.3118816452491181
#                 EV: -2.022947931712963
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: points
#             THRESH: 20.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.6881183547508819
#                 EV: 1.307751585216418
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: points
#             THRESH: 21.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.5079193011453424
#                 EV: -0.3440730728343606
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: points
#             THRESH: 21.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.49208069885465755
#                 EV: -0.1963550826092959
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: points
#             THRESH: 9.5
#               ODDS: -105
#               TYPE: over
#               PROB: 0.6723691021924281
#                 EV: 1.5636031404498922
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: points
#             THRESH: 9.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.3276308978075719
#                 EV: -2.10172667324071
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.4714829505372484
#                 EV: -0.7566534451647637
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.5285170494627516
#                 EV: -0.05951453763080039
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: assists
#             THRESH: 6.5
#               ODDS: -105
#               TYPE: over
#               PROB: 0.6666956358042396
#                 EV: 1.5082193018985288
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: assists
#             THRESH: 6.5
#               ODDS: -135
#               TYPE: under
#               PROB: 0.33330436419576037
#                 EV: -2.099017570888752
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: assists
#             THRESH: 4.5
#               ODDS: 110
#               TYPE: over
#               PROB: 0.6137558852314517
#                 EV: 1.444436794930243
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -160
#               TYPE: under
#               PROB: 0.38624411476854825
#                 EV: -1.8617665675055455
#         HOUSE_PROB: 0.6153846153846154
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -155
#               TYPE: over
#               PROB: 0.5677887756457282
#                 EV: -0.3294794261399785
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: assists
#             THRESH: 2.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.43221122435427184
#                 EV: -0.4617821442801455
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: assists
#             THRESH: 0.5
#               ODDS: -250
#               TYPE: over
#               PROB: 0.5506710358827783
#                 EV: -1.1453027488205518
#         HOUSE_PROB: 0.7142857142857143
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: assists
#             THRESH: 0.5
#               ODDS: 170
#               TYPE: under
#               PROB: 0.4493289641172217
#                 EV: 1.0659410155824922
#         HOUSE_PROB: 0.37037037037037035
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: assists
#             THRESH: 3.5
#               ODDS: -170
#               TYPE: over
#               PROB: 0.5016645070629165
#                 EV: -1.0161936203827215
#         HOUSE_PROB: 0.6296296296296295
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: assists
#             THRESH: 3.5
#               ODDS: 120
#               TYPE: under
#               PROB: 0.49833549293708346
#                 EV: 0.4816904223079179
#         HOUSE_PROB: 0.45454545454545453
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: assists
#             THRESH: 0.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.6014809589154859
#                 EV: 0.7414091532841844
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: assists
#             THRESH: 0.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.39851904108451414
#                 EV: -1.4746392519446823
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.5005177442143811
#                 EV: -0.4119206780348392
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.4994822557856189
#                 EV: -0.33092673939530215
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: assists
#             THRESH: 8.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.5390655806697856
#                 EV: -0.14840977397192923
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: assists
#             THRESH: 8.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.4609344193302144
#                 EV: -0.6001714518479533
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -155
#               TYPE: over
#               PROB: 0.5857115890686466
#                 EV: -0.18204983185468127
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: assists
#             THRESH: 2.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.41428841093135343
#                 EV: -0.6499716852207893
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -165
#               TYPE: over
#               PROB: 0.6815360251474281
#                 EV: 0.4729408080020736
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: assists
#             THRESH: 4.5
#               ODDS: 115
#               TYPE: under
#               PROB: 0.318463974852572
#                 EV: -1.576512270334851
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.5371631129795577
#                 EV: -0.39574474588950537
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: assists
#             THRESH: 1.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.46283688702044234
#                 EV: -0.3716311297955768
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -145
#               TYPE: over
#               PROB: 0.593994150290162
#                 EV: 0.018226442106541896
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: assists
#             THRESH: 1.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.40600584970983794
#                 EV: -0.8384400404741612
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: assists
#             THRESH: 4.5
#               ODDS: 110
#               TYPE: over
#               PROB: 0.4101729786894224
#                 EV: -0.6931837237610647
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -155
#               TYPE: under
#               PROB: 0.5898270213105776
#                 EV: -0.1481970827678296
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.566529879633291
#                 EV: 0.8069312662412331
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: -150
#               TYPE: under
#               PROB: 0.43347012036670896
#                 EV: -1.3877489969440924
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -135
#               TYPE: over
#               PROB: 0.32286984929357265
#                 EV: -2.1898364968892747
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.6771301507064273
#                 EV: 1.6100800426103614
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: 115
#               TYPE: over
#               PROB: 0.4714829505372484
#                 EV: 0.06844171827542045
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: -165
#               TYPE: under
#               PROB: 0.5285170494627516
#                 EV: -0.7558479361324499
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: 115
#               TYPE: over
#               PROB: 0.4714829505372484
#                 EV: 0.06844171827542045
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: -160
#               TYPE: under
#               PROB: 0.5285170494627516
#                 EV: -0.7057989731151437
#         HOUSE_PROB: 0.6153846153846154
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: -260
#               TYPE: over
#               PROB: 0.6988057880877979
#                 EV: -0.1621137747767838
#         HOUSE_PROB: 0.7222222222222222
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: 175
#               TYPE: under
#               PROB: 0.3011942119122021
#                 EV: -0.8585795862072212
#         HOUSE_PROB: 0.36363636363636365
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.4354585328081444
#                 EV: -1.008296782592009
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5645414671918556
#                 EV: 0.17496344925867735
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.36172899226219113
#                 EV: -1.3827100773780887
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: -140
#               TYPE: under
#               PROB: 0.6382710077378089
#                 EV: 0.4708943520383624
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: 130
#               TYPE: over
#               PROB: 0.38799135002455154
#                 EV: -0.5380994747176571
#         HOUSE_PROB: 0.4347826086956522
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: -185
#               TYPE: under
#               PROB: 0.6120086499754485
#                 EV: -0.28587931775668096
#         HOUSE_PROB: 0.6491228070175439
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 155
#               TYPE: over
#               PROB: 0.4218962688156227
#                 EV: 0.37917742739918925
#         HOUSE_PROB: 0.3921568627450981
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -225
#               TYPE: under
#               PROB: 0.5781037311843773
#                 EV: -0.8248063858906081
#         HOUSE_PROB: 0.6923076923076923
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: -240
#               TYPE: over
#               PROB: 0.5682894765709202
#                 EV: -0.9746162076226481
#         HOUSE_PROB: 0.7058823529411764
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: 165
#               TYPE: under
#               PROB: 0.4317105234290798
#                 EV: 0.720164435435307
#         HOUSE_PROB: 0.37735849056603776
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 170
#               TYPE: over
#               PROB: 0.3517793518165264
#                 EV: -0.250978750476893
#         HOUSE_PROB: 0.37037037037037035
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -250
#               TYPE: under
#               PROB: 0.6482206481834736
#                 EV: -0.4624554627156847
#         HOUSE_PROB: 0.7142857142857143
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: 170
#               TYPE: over
#               PROB: 0.4054794520298056
#                 EV: 0.4739726024023758
#         HOUSE_PROB: 0.37037037037037035
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: -250
#               TYPE: under
#               PROB: 0.5945205479701944
#                 EV: -0.8383561642086397
#         HOUSE_PROB: 0.7142857142857143
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: rebounds
#             THRESH: 12.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.2810890719568403
#                 EV: -2.4233501737289638
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: rebounds
#             THRESH: 12.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.7189109280431597
#                 EV: 1.5900168403956316
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.4407062483387585
#                 EV: -1.0336437649511736
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.5592937516612415
#                 EV: 0.33871308403912437
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: rebounds
#             THRESH: 10.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.1801636969911209
#                 EV: -3.2802556196302097
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: rebounds
#             THRESH: 10.5
#               ODDS: -125
#               TYPE: under
#               PROB: 0.8198363030088791
#                 EV: 2.3785267270799118
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.4256935667087164
#                 EV: -1.3511979996395733
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.5743064332912836
#                 EV: 0.7430643329128364
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: -165
#               TYPE: over
#               PROB: 0.48478388953385176
#                 EV: -1.107038462834221
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: 115
#               TYPE: under
#               PROB: 0.5152161104661482
#                 EV: 0.5385731875110933
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: 125
#               TYPE: over
#               PROB: 0.1501656330485931
#                 EV: -3.3106366282033277
#         HOUSE_PROB: 0.4444444444444444
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: -175
#               TYPE: under
#               PROB: 0.8498343669514069
#                 EV: 1.6772700260467683
#         HOUSE_PROB: 0.6363636363636364
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: rebounds
#             THRESH: 5.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.5150434175302715
#                 EV: 0.2791950296852832
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: rebounds
#             THRESH: 5.5
#               ODDS: -150
#               TYPE: under
#               PROB: 0.4849565824697285
#                 EV: -0.9586951460855966
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.4564712858513804
#                 EV: -0.8156798796956792
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5435287141486196
#                 EV: -0.017653453637652916
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: rebounds
#             THRESH: 7.5
#               ODDS: -150
#               TYPE: over
#               PROB: 0.5853939420183494
#                 EV: -0.12171714984708881
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: rebounds
#             THRESH: 7.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.4146060579816506
#                 EV: -0.7502879056880811
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.4302912533424894
#                 EV: -0.5895146532394833
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -150
#               TYPE: under
#               PROB: 0.5697087466575106
#                 EV: -0.2524271111874121
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -155
#               TYPE: over
#               PROB: 0.45104640759803694
#                 EV: -1.289779550403245
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.5489535924019631
#                 EV: 0.7640127202206122
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -165
#               TYPE: over
#               PROB: 0.4411332142972987
#                 EV: -1.4575666124610867
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: 115
#               TYPE: under
#               PROB: 0.5588667857027013
#                 EV: 1.0078179463040389
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: -170
#               TYPE: over
#               PROB: 0.6264311686747459
#                 EV: -0.02539954287701729
#         HOUSE_PROB: 0.6296296296296295
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: 120
#               TYPE: under
#               PROB: 0.37356883132525404
#                 EV: -0.8907428554222054
#         HOUSE_PROB: 0.45454545454545453
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: rebounds
#             THRESH: 6.5
#               ODDS: -160
#               TYPE: over
#               PROB: 0.47032432454470485
#                 EV: -1.178614863074273
#         HOUSE_PROB: 0.6153846153846154
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: rebounds
#             THRESH: 6.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.5296756754552951
#                 EV: 0.5615945922805992
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: fgm
#             THRESH: 5.5
#               ODDS: -135
#               TYPE: over
#               PROB: 0.3629934862895352
#                 EV: -1.8406122489614525
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: fgm
#             THRESH: 5.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.6370065137104648
#                 EV: 1.370065137104648
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: fgm
#             THRESH: 6.5
#               ODDS: 110
#               TYPE: over
#               PROB: 0.5077926095189602
#                 EV: 0.3318223999490826
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: fgm
#             THRESH: 6.5
#               ODDS: -145
#               TYPE: under
#               PROB: 0.4922073904810398
#                 EV: -0.8416961838670769
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.6543184471393919
#                 EV: 1.5431844713939196
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.34568155286060803
#                 EV: -1.942047801617698
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.1965992882057932
#                 EV: -3.034007117942068
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.8034007117942068
#                 EV: 2.1070062966410603
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: fgm
#             THRESH: 12.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.4560233327450679
#                 EV: -1.0912285764708458
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: fgm
#             THRESH: 12.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.5439766672549321
#                 EV: 0.7117550061767872
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: -160
#               TYPE: over
#               PROB: 0.5016872406351934
#                 EV: -0.9237911698390535
#         HOUSE_PROB: 0.6153846153846154
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: 120
#               TYPE: under
#               PROB: 0.49831275936480657
#                 EV: 0.48144035301287236
#         HOUSE_PROB: 0.45454545454545453
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: fgm
#             THRESH: 2.5
#               ODDS: 145
#               TYPE: over
#               PROB: 0.36654217516213006
#                 EV: -0.5098583542639066
#         HOUSE_PROB: 0.4081632653061224
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: fgm
#             THRESH: 2.5
#               ODDS: -195
#               TYPE: under
#               PROB: 0.6334578248378699
#                 EV: -0.20846004289303544
#         HOUSE_PROB: 0.6610169491525424
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: fgm
#             THRESH: 8.5
#               ODDS: -130
#               TYPE: over
#               PROB: 0.5390655806697856
#                 EV: -0.23134294022881896
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: fgm
#             THRESH: 8.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.4609344193302144
#                 EV: -0.5004020970145744
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.6872816501433185
#                 EV: 1.3000817929804205
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.3127183498566814
#                 EV: -2.014961205913495
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: fgm
#             THRESH: 7.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.35964472424992244
#                 EV: -1.6381036646202904
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: fgm
#             THRESH: 7.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.6403552757500776
#                 EV: 0.985929751576812
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.6264311686747459
#                 EV: 0.9795702464407574
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.37356883132525404
#                 EV: -1.575619046185171
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.5100132102562286
#                 EV: 0.10013210256228611
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.4899867897437714
#                 EV: -0.66550147534356
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: fgm
#             THRESH: 6.5
#               ODDS: 110
#               TYPE: over
#               PROB: 0.3936972175874087
#                 EV: -0.8661792153322088
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: fgm
#             THRESH: 6.5
#               ODDS: -145
#               TYPE: under
#               PROB: 0.6063027824125913
#                 EV: 0.12221316176154762
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -130
#               TYPE: over
#               PROB: 0.6543184471393919
#                 EV: 0.7882016477715439
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.34568155286060803
#                 EV: -1.5431844713939196
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -135
#               TYPE: over
#               PROB: 0.6465453180412198
#                 EV: 0.6273388792476542
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.35345468195878016
#                 EV: -1.3770895099225036
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 115
#               TYPE: over
#               PROB: 0.27385096292630895
#                 EV: -2.0561021485421787
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -150
#               TYPE: under
#               PROB: 0.726149037073691
#                 EV: 1.051241975614091
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: steals
#             THRESH: 1.5
#               ODDS: 140
#               TYPE: over
#               PROB: 0.40816728654014434
#                 EV: -0.10199256151826752
#         HOUSE_PROB: 0.4166666666666667
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: steals
#             THRESH: 1.5
#               ODDS: -190
#               TYPE: under
#               PROB: 0.5918327134598557
#                 EV: -0.48338192359583854
#         HOUSE_PROB: 0.6551724137931035
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -165
#               TYPE: over
#               PROB: 0.5852170883184187
#                 EV: -0.30052944229148704
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 125
#               TYPE: under
#               PROB: 0.4147829116815813
#                 EV: -0.3336922435822105
#         HOUSE_PROB: 0.4444444444444444
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -190
#               TYPE: over
#               PROB: 0.5506710358827783
#                 EV: -0.797510515631429
#         HOUSE_PROB: 0.6551724137931035
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 140
#               TYPE: under
#               PROB: 0.4493289641172217
#                 EV: 0.39194756940666053
#         HOUSE_PROB: 0.4166666666666667
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: steals
#             THRESH: 1.5
#               ODDS: 165
#               TYPE: over
#               PROB: 0.27895244880408865
#                 EV: -1.3038800533458255
#         HOUSE_PROB: 0.37735849056603776
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: steals
#             THRESH: 1.5
#               ODDS: -225
#               TYPE: under
#               PROB: 0.7210475511959114
#                 EV: 0.20756564752602635
#         HOUSE_PROB: 0.6923076923076923
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 160
#               TYPE: over
#               PROB: 0.3296799539643607
#                 EV: -0.7141605984633115
#         HOUSE_PROB: 0.3846153846153846
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -220
#               TYPE: under
#               PROB: 0.6703200460356393
#                 EV: -0.12494511974080424
#         HOUSE_PROB: 0.6875
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.38121660819385905
#                 EV: -1.4364534451443611
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.618783391806141
#                 EV: 0.7842795321008822
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: steals
#             THRESH: 1.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.4620516577260423
#                 EV: -1.0395572194910656
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: steals
#             THRESH: 1.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.5379483422739577
#                 EV: 0.5139705083080663
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.4511883639059735
#                 EV: -0.6932019808975252
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5488116360940265
#                 EV: 0.030773330861910253
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.47270757595695134
#                 EV: -0.2729242404304868
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -135
#               TYPE: under
#               PROB: 0.5272924240430487
#                 EV: -0.41060297592161366
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.428790936151185
#                 EV: -1.0694164186141366
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.571209063848815
#                 EV: 0.5760884804289077
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -175
#               TYPE: over
#               PROB: 0.5323335729900907
#                 EV: -0.8173790693635734
#         HOUSE_PROB: 0.6363636363636364
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 130
#               TYPE: under
#               PROB: 0.46766642700990935
#                 EV: 0.3781639106139574
#         HOUSE_PROB: 0.4347826086956522
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: steals
#             THRESH: 0.5
#               ODDS: -175
#               TYPE: over
#               PROB: 0.4511883639059735
#                 EV: -1.4549485693102082
#         HOUSE_PROB: 0.6363636363636364
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: steals
#             THRESH: 0.5
#               ODDS: 130
#               TYPE: under
#               PROB: 0.5488116360940265
#                 EV: 1.311333815081305
#         HOUSE_PROB: 0.4347826086956522
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.3559635789168586
#                 EV: -1.6021658376118038
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Josh Hart
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.6440364210831414
#                 EV: 0.9036671932621303
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -130
#               TYPE: over
#               PROB: 0.5682894765709202
#                 EV: 0.02717613889660253
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Donte DiVincenzo
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.4317105234290798
#                 EV: -0.6828947657092019
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -240
#               TYPE: over
#               PROB: 0.6865138191173947
#                 EV: -0.13719378125178672
#         HOUSE_PROB: 0.7058823529411764
#
# Prop object created.
#
#             PLAYER: Isaiah Hartenstein
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 175
#               TYPE: under
#               PROB: 0.3134861808826053
#                 EV: -0.6895650128641764
#         HOUSE_PROB: 0.36363636363636365
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 250
#               TYPE: over
#               PROB: 0.11307956328284252
#                 EV: -3.021107642550256
#         HOUSE_PROB: 0.2857142857142857
#
# Prop object created.
#
#             PLAYER: Miles McBride
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -350
#               TYPE: under
#               PROB: 0.8869204367171575
#                 EV: 0.7016313788960122
#         HOUSE_PROB: 0.7777777777777779
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 350
#               TYPE: over
#               PROB: 0.07688365361336424
#                 EV: -3.2701177936993044
#         HOUSE_PROB: 0.2222222222222222
#
# Prop object created.
#
#             PLAYER: Alec Burks
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -525
#               TYPE: under
#               PROB: 0.9231163463866358
#                 EV: 0.4947401570633083
#         HOUSE_PROB: 0.84
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 375
#               TYPE: over
#               PROB: 0.07688365361336424
#                 EV: -3.1740132266825993
#         HOUSE_PROB: 0.21052631578947367
#
# Prop object created.
#
#             PLAYER: Jalen Brunson
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -575
#               TYPE: under
#               PROB: 0.9231163463866358
#                 EV: 0.41829159835633956
#         HOUSE_PROB: 0.851851851851852
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -180
#               TYPE: over
#               PROB: 0.6465453180412198
#                 EV: 0.02868580698726575
#         HOUSE_PROB: 0.6428571428571428
#
# Prop object created.
#
#             PLAYER: Precious Achiuwa
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 135
#               TYPE: under
#               PROB: 0.35345468195878016
#                 EV: -0.8469074869843327
#         HOUSE_PROB: 0.425531914893617
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.49338300763441034
#                 EV: 0.057175828252706395
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -140
#               TYPE: under
#               PROB: 0.5066169923655897
#                 EV: -0.6575686368663733
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.5132477440400285
#                 EV: 0.2607893764102922
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -140
#               TYPE: under
#               PROB: 0.4867522559599715
#                 EV: -0.8278378060573859
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 120
#               TYPE: over
#               PROB: 0.3296799539643607
#                 EV: -1.3735205063920324
#         HOUSE_PROB: 0.45454545454545453
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -160
#               TYPE: under
#               PROB: 0.6703200460356393
#                 EV: 0.4463503740395698
#         HOUSE_PROB: 0.6153846153846154
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 130
#               TYPE: over
#               PROB: 0.38121660819385905
#                 EV: -0.6160090057706213
#         HOUSE_PROB: 0.4347826086956522
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -175
#               TYPE: under
#               PROB: 0.618783391806141
#                 EV: -0.13813049295174995
#         HOUSE_PROB: 0.6363636363636364
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: blocks
#             THRESH: 1.5
#               ODDS: -155
#               TYPE: over
#               PROB: 0.5371631129795577
#                 EV: -0.5814001996842846
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: blocks
#             THRESH: 1.5
#               ODDS: 115
#               TYPE: under
#               PROB: 0.46283688702044234
#                 EV: -0.024503464530244656
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 325
#               TYPE: over
#               PROB: 0.11307956328284252
#                 EV: -2.5970592802395966
#         HOUSE_PROB: 0.23529411764705882
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -475
#               TYPE: under
#               PROB: 0.8869204367171575
#                 EV: 0.3682026432880585
#         HOUSE_PROB: 0.8260869565217391
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: 425
#               TYPE: over
#               PROB: 0.11307956328284252
#                 EV: -2.031661463825384
#         HOUSE_PROB: 0.19047619047619047
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: blocks
#             THRESH: 0.5
#               ODDS: -700
#               TYPE: under
#               PROB: 0.8869204367171575
#                 EV: 0.06811678124089937
#         HOUSE_PROB: 0.875
#
# Prop object created.
# num of props: 192
# num of profitable props: 72

# %%
top_ev = profitable_props_df.sort_values(by="PROB", ascending=False).head(24)
parlays = generate_heterogenous_combinations(profitable_props_df, 6)

# %%
candidates = []

for i, parlay in enumerate(parlays):
    df, score = parlay
    today = date.today()
    
    probs = list(df['PROB'])
    odds = [odds for odds in list(df['ODDS'])]
    combined_ev = analyze.analyze_parlay(probs, odds, 5)
    combined_prob = analyze.calculate_combined_probability(probs)
    df['COMBINED EV'] = combined_ev
    df['COMBINED PROB'] = combined_prob

    parlay_tag = f"{today}_{i}_"
    candidate = [parlay_tag]
    props = []
    for _, row in df.iterrows():
        prop_info = f"{row['PLAYER']}_{row['STAT']}_{row['THRESH']}_{row['ODDS']}_{row['TYPE']}_P{row['PROB']:.3f}_EV{row['EV']:.3f}_HOUSE_PROV{row['HOUSE_PROB']:.3f}"
        props.append(prop_info)
    candidate.append(" + ".join(props))
    candidate += [combined_prob, combined_ev, score]
    candidates.append(candidate)

# %%
candidates_df = pd.DataFrame.from_records(candidates, columns = ["parlay_tag", "props", "COMBINED_PROB", "COMBINED_EV", "HETERO"])
candidates_df.to_csv(f"prop_lines/{date.today()}_candidates_7props.csv")
