# %%
import pandas as pd
import itertools
from itertools import combinations
from datetime import datetime, date
from data_manager import DataManager
import analyze
from models import Player

dm = DataManager()

class Prop:
    def __init__(self, name, team, stat, threshold, odds, bet_type):
        self.name = name
        self.team = team
        self.stat = stat
        self.n = threshold
        self.odds = odds
        self.bet_type = bet_type
        self.probability = self.get_prop_probability()
        self.ev, self.house_prob = self.get_ev_and_implied_prob()
        self.print_out = f"""
            PLAYER: {self.name}
              STAT: {self.stat}
            THRESH: {self.n}
              ODDS: {self.odds}
              TYPE: {self.bet_type}
              PROB: {self.probability}
                EV: {self.ev}
        HOUSE_PROB: {self.house_prob}
            """
        print(self.print_out)
        self.entry = {
            "PLAYER": self.name,
              "TEAM": self.team,
              "STAT": self.stat,
            "THRESH": self.n,
              "ODDS": self.odds,
              "TYPE": self.bet_type,
              "PROB": self.probability,
                "EV": self.ev,
        "HOUSE_PROB": self.house_prob
        }
    
    def get_prop_probability(self, last_n_games=25):
        player_id = dm.get_player_id(self.name)
        data = dm.get_and_save_player_data(player_id, self.name).sort_values(by='date', ascending=False).head(last_n_games).copy()
        # print(data.head())
        if self.bet_type == "over":
            return analyze.estimate_probability_poisson_over(data, self.stat, self.n)
        elif self.bet_type == "under":
            return analyze.estimate_probability_poisson_under(data, self.stat, self.n)
        else:
            raise ValueError("Invalid bet type. Use 'over' or 'under'.")
        
    def get_ev_and_implied_prob(self):
        odds = self.american_to_decimal(self.odds)
        house_probability = analyze.estimate_implied_probability(odds)
        ev = analyze.calculate_ev(self.probability, odds, 5)
        return ev, house_probability
    
    @staticmethod
    def american_to_decimal(american_odds):
        """Convert American odds to decimal odds."""
        if american_odds > 0:
            return 1 + (american_odds / 100)
        else:
            return 1 + (100 / abs(american_odds))
    

def extract_raw_data(file_path): # .csv
    # gets input from A1
    # Sample input text (use the content of your file here)
    raw_input = pd.read_csv(file_path)
    list_of_raw_input = list(raw_input.iloc[:, 0])
    return list_of_raw_input


def load_available_props():
    
    raw_input = extract_raw_data("prop_lines/prop_lines.csv")
    print("Received raw input.")
    stat_names = {
             'PointsSGP': "points",
            'AssistsSGP': "assists",
        'Threes MadeSGP': "fg3m",
           'ReboundsSGP': "rebounds",
   'Field Goals MadeSGP': "fgm",
             'StealsSGP': "steals",
             'BlocksSGP': "blocks",
        }
    #debug stat_name_inputs = extract_raw_data("prop_lines/player_prop_categories.csv")
    players = dm.query_players()
    player_names = [player.name for player in players]
    teams = dm.query_teams()
    team_names = [team.nickname for team in teams]
    row_of_interest = 0
    current_category = None
    current_player = None
    current_team = None
    records = []
    for _, item in enumerate(raw_input):
        if item is None: 
            continue
        if item in stat_names:
            current_category = stat_names[item]
            print(f"Loading {current_category} props.")
        if item != current_team:
            if item in team_names:
                current_team = item
        if item in player_names:
            current_player = item 
            assert current_team
            record = [current_player, current_team, current_category]
            row_of_interest = 6


        if row_of_interest:
            row_of_interest -= 1
            if row_of_interest < 5:
                record.append(item)
                if row_of_interest == 1:
                    records.append(record)
                    record = []
    df = pd.DataFrame.from_records(records, columns=["player_name", "team", "stat", "over_threshold", "over_odds", "under_threshold", "under_odds"])
    
    df['player_name'] = df['player_name'].astype(str)
    df['team'] = df['team'].astype(str)
    df['stat'] = df['stat'].astype(str)
    df['over_threshold'] = df['over_threshold'].str.extract(r'(\d+\.\d+)').astype(float)
    df['under_threshold'] = df['under_threshold'].str.extract(r'(\d+\.\d+)').astype(float)
    df['over_odds'] = df['over_odds'].astype(int)
    df['under_odds'] = df['under_odds'].astype(int)

    return df


def get_analyzed_props(available_props):
    props = []
    for _, row in available_props.iterrows():
        print(row)
        for bet_type in ["over", "under"]:
            prop = Prop(
                    name=row["player_name"], 
                    team=row["team"],
                    stat=row["stat"], 
                threshold=row[f"{bet_type}_threshold"], 
                    odds=row[f"{bet_type}_odds"], 
                bet_type=bet_type
                )
            props.append(prop)    
            print("Prop object created.")

    return props


def generate_heterogenous_combinations(df, n):

    # Generate all combinations of n rows
    combinations = list(itertools.combinations(df.index, n))

    # Function to evaluate heterogeneity of a combination
    def evaluate_heterogeneity(comb, df):
        comb_list = list(comb)
        players = df.loc[comb_list, 'PLAYER']
        stats = df.loc[comb_list, 'STAT']
        teams = df.loc[comb_list, 'TEAM']
        # Calculate a simple heterogeneity score (you can define your own logic)
        player_score = len(set(players))
        stat_score = len(set(stats))
        team_score = len(set(teams))
        return player_score + stat_score + team_score

    # Evaluate all combinations and sort them by heterogeneity score
    comb_scores = [(comb, evaluate_heterogeneity(comb, df)) for comb in combinations]
    comb_scores_sorted = sorted(comb_scores, key=lambda x: x[1], reverse=True)

    # Select the most heterogeneous combinations (you can define how many you want)
    top_combinations = comb_scores_sorted # Top 5 combinations for example

    # Display the most heterogeneous combinations
    for comb, score in top_combinations:
        print(f"Combination: {comb}, Score: {score}")
        print(df.loc[list(comb)])
        print()

    # Optional: Convert combinations to DataFrame
    top_comb_dfs = [(df.loc[list(comb)], score) for comb, score in top_combinations]

    return top_comb_dfs


def generate_unique_combinations(df, combo_length):
    all_combinations = list(combinations(df.index, combo_length))
    
    unique_combinations = set()
    valid_combinations = []
    
    for combo in all_combinations:
        players_in_combo = df.loc[list(combo), 'Player']
        if players_in_combo.duplicated().sum() == 0:
            sorted_combo = tuple(sorted(df.loc[list(combo)].apply(lambda row: (row['Player'], row['Category'], row['Bet']), axis=1)))
            if sorted_combo not in unique_combinations:
                unique_combinations.add(sorted_combo)
                valid_combinations.append(combo)
    
    return valid_combinations

# %%
available_props = load_available_props()
analyzed_props = get_analyzed_props(available_props)
print(analyzed_props)
filter_players = ['Naz Reid', 'Rudy Gobert', "Nickeil Alexander-Walker"]
filtered_df = dm.filter_props(analyzed_props, filter_players)
print(filtered_df.head(5))
# parlays = generate_unique_combinations(filtered_df, 4)


def generate_unique_combinations(df, combo_length):
    all_combinations = list(combinations(df.index, combo_length))
    
    unique_combinations = set()
    valid_combinations = []
    
    for combo in all_combinations:
        players_in_combo = df.loc[list(combo), 'PLAYER']
        if players_in_combo.duplicated().sum() == 0:
            # Create a sorted tuple based on all columns for uniqueness
            sorted_combo = tuple(sorted(df.loc[list(combo)].apply(lambda row: (row['PLAYER'], row['TEAM'], row['STAT'], row['THRESH'], row['ODDS'], row['TYPE']), axis=1)))
            if sorted_combo not in unique_combinations:
                unique_combinations.add(sorted_combo)
                valid_combinations.append(combo)
    
    return valid_combinations

# Generate valid and unique combinations of length 2
valid_combos = generate_unique_combinations(filtered_df, 3)

# Create a list of dataframes for each valid combination
combo_dfs = [filtered_df.loc[list(combo)].reset_index(drop=True) for combo in valid_combos]

# Display each dataframe
for i, combo_df in enumerate(combo_dfs):
    print(f"Combination {i+1}:\n{combo_df}\n")
# Out:
# Received raw input.
# Loading points props.
# Loading assists props.
# Loading fg3m props.
# Loading rebounds props.
# Loading fgm props.
# Loading steals props.
# Loading blocks props.
# player_name        Obi Toppin
# team                   Pacers
# stat                   points
# over_threshold            7.5
# over_odds                -135
# under_threshold           7.5
# under_odds                100
# Name: 0, dtype: object
#
#             PLAYER: Obi Toppin
#               STAT: points
#             THRESH: 7.5
#               ODDS: -135
#               TYPE: over
#               PROB: 0.8618999066487378
#                 EV: 2.5017214097204965
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: points
#             THRESH: 7.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.13810009335126217
#                 EV: -3.6189990664873783
#         HOUSE_PROB: 0.5
#
# Prop object created.
# player_name        Aaron Nesmith
# team                      Pacers
# stat                      points
# over_threshold               9.5
# over_odds                   -120
# under_threshold              9.5
# under_odds                  -110
# Name: 1, dtype: object
#
#             PLAYER: Aaron Nesmith
#               STAT: points
#             THRESH: 9.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.6551326000263189
#                 EV: 1.005382166907924
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: points
#             THRESH: 9.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.34486739997368104
#                 EV: -1.7080839093421352
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
# player_name        T.J. McConnell
# team                       Pacers
# stat                       points
# over_threshold                9.5
# over_odds                    -140
# under_threshold               9.5
# under_odds                    105
# Name: 2, dtype: object
#
#             PLAYER: T.J. McConnell
#               STAT: points
#             THRESH: 9.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.8119961703007408
#                 EV: 1.9599671740063505
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: points
#             THRESH: 9.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.18800382969925922
#                 EV: -3.072960745582593
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
# player_name        Tyrese Haliburton
# team                          Pacers
# stat                          points
# over_threshold                  19.5
# over_odds                       -110
# under_threshold                 19.5
# under_odds                      -120
# Name: 3, dtype: object
#
#             PLAYER: Tyrese Haliburton
#               STAT: points
#             THRESH: 19.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.42117441054779736
#                 EV: -0.9796988084073881
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: points
#             THRESH: 19.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5788255894522026
#                 EV: 0.30590123664519187
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Andrew Nembhard
# team                        Pacers
# stat                        points
# over_threshold                10.5
# over_odds                     -130
# under_threshold               10.5
# under_odds                     100
# Name: 4, dtype: object
#
#             PLAYER: Andrew Nembhard
#               STAT: points
#             THRESH: 10.5
#               ODDS: -130
#               TYPE: over
#               PROB: 0.6271170949771379
#                 EV: 0.547574301720835
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: points
#             THRESH: 10.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.3728829050228621
#                 EV: -1.271170949771379
#         HOUSE_PROB: 0.5
#
# Prop object created.
# player_name        Myles Turner
# team                     Pacers
# stat                     points
# over_threshold             15.5
# over_odds                  -125
# under_threshold            15.5
# under_odds                 -105
# Name: 5, dtype: object
#
#             PLAYER: Myles Turner
#               STAT: points
#             THRESH: 15.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.6285463439246328
#                 EV: 0.6569170953216954
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: points
#             THRESH: 15.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.3714536560753671
#                 EV: -1.3739047859309403
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
# player_name        Pascal Siakam
# team                      Pacers
# stat                      points
# over_threshold              20.5
# over_odds                   -105
# under_threshold             20.5
# under_odds                  -125
# Name: 6, dtype: object
#
#             PLAYER: Pascal Siakam
#               STAT: points
#             THRESH: 20.5
#               ODDS: -105
#               TYPE: over
#               PROB: 0.5967714951200283
#                 EV: 0.8256264999812277
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: points
#             THRESH: 20.5
#               ODDS: -125
#               TYPE: under
#               PROB: 0.4032285048799717
#                 EV: -1.370943456080255
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
# player_name        Jaylen Brown
# team                    Celtics
# stat                     points
# over_threshold             24.5
# over_odds                  -120
# under_threshold            24.5
# under_odds                 -110
# Name: 7, dtype: object
#
#             PLAYER: Jaylen Brown
#               STAT: points
#             THRESH: 24.5
#               ODDS: -120
#               TYPE: over
#               PROB: 0.46546738848078717
#                 EV: -0.7332156055927834
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
#
#             PLAYER: Jaylen Brown
#               STAT: points
#             THRESH: 24.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.5345326115192128
#                 EV: 0.10235674631975922
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
# player_name        Jayson Tatum
# team                    Celtics
# stat                     points
# over_threshold             29.5
# over_odds                  -110
# under_threshold            29.5
# under_odds                 -120
# Name: 8, dtype: object
#
#             PLAYER: Jayson Tatum
#               STAT: points
#             THRESH: 29.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.2308282571485959
#                 EV: -2.7966393635815843
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Jayson Tatum
#               STAT: points
#             THRESH: 29.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.7691717428514041
#                 EV: 2.050740976137872
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Al Horford
# team                  Celtics
# stat                   points
# over_threshold            9.5
# over_odds                -115
# under_threshold           9.5
# under_odds               -115
# Name: 9, dtype: object
#
#             PLAYER: Al Horford
#               STAT: points
#             THRESH: 9.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.5619210686802503
#                 EV: 0.2527404246197307
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Al Horford
#               STAT: points
#             THRESH: 9.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.4380789313197498
#                 EV: -0.9049143376632083
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
# player_name        Jrue Holiday
# team                    Celtics
# stat                     points
# over_threshold             12.5
# over_odds                  -110
# under_threshold            12.5
# under_odds                 -120
# Name: 10, dtype: object
#
#             PLAYER: Jrue Holiday
#               STAT: points
#             THRESH: 12.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.2601037783965321
#                 EV: -2.5171912062149207
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Jrue Holiday
#               STAT: points
#             THRESH: 12.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.7398962216034679
#                 EV: 1.782382031365123
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Derrick White
# team                     Celtics
# stat                      points
# over_threshold              16.5
# over_odds                   -110
# under_threshold             16.5
# under_odds                  -120
# Name: 11, dtype: object
#
#             PLAYER: Derrick White
#               STAT: points
#             THRESH: 16.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.47760659761348245
#                 EV: -0.44102793187130285
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Derrick White
#               STAT: points
#             THRESH: 16.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5223934023865175
#                 EV: -0.21139381145692226
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Payton Pritchard
# team                        Celtics
# stat                         points
# over_threshold                  9.5
# over_odds                      -115
# under_threshold                 9.5
# under_odds                     -110
# Name: 12, dtype: object
#
#             PLAYER: Payton Pritchard
#               STAT: points
#             THRESH: 9.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.8368140518122709
#                 EV: 2.822392223462532
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Payton Pritchard
#               STAT: points
#             THRESH: 9.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.16318594818772914
#                 EV: -3.4423159491171305
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
# player_name        Luke Kornet
# team                   Celtics
# stat                    points
# over_threshold             3.5
# over_odds                 -175
# under_threshold            3.5
# under_odds                 130
# Name: 13, dtype: object
#
#             PLAYER: Luke Kornet
#               STAT: points
#             THRESH: 3.5
#               ODDS: -175
#               TYPE: over
#               PROB: 0.7770568098504246
#                 EV: 1.1054463631104783
#         HOUSE_PROB: 0.6363636363636364
#
# Prop object created.
#
#             PLAYER: Luke Kornet
#               STAT: points
#             THRESH: 3.5
#               ODDS: 130
#               TYPE: under
#               PROB: 0.22294319014957542
#                 EV: -2.4361533132798825
#         HOUSE_PROB: 0.4347826086956522
#
# Prop object created.
# player_name        Myles Turner
# team                     Pacers
# stat                    assists
# over_threshold              1.5
# over_odds                  -125
# under_threshold             1.5
# under_odds                 -115
# Name: 14, dtype: object
#
#             PLAYER: Myles Turner
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.5605404954201741
#                 EV: 0.044864458781566974
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.43945950457982585
#                 EV: -0.8920089789277146
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
# player_name        T.J. McConnell
# team                       Pacers
# stat                      assists
# over_threshold                4.5
# over_odds                    -135
# under_threshold               4.5
# under_odds                   -105
# Name: 15, dtype: object
#
#             PLAYER: T.J. McConnell
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -135
#               TYPE: over
#               PROB: 0.6872816501433185
#                 EV: 0.981895843839995
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.3127183498566814
#                 EV: -1.947273251399063
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
# player_name        Tyrese Haliburton
# team                          Pacers
# stat                         assists
# over_threshold                   8.5
# over_odds                        105
# under_threshold                  8.5
# under_odds                      -150
# Name: 16, dtype: object
#
#             PLAYER: Tyrese Haliburton
#               STAT: assists
#             THRESH: 8.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.5069253994127562
#                 EV: 0.19598534398075085
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: assists
#             THRESH: 8.5
#               ODDS: -150
#               TYPE: under
#               PROB: 0.49307460058724384
#                 EV: -0.8910449951063022
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
# player_name        Aaron Nesmith
# team                      Pacers
# stat                     assists
# over_threshold               1.5
# over_odds                   -140
# under_threshold              1.5
# under_odds                   100
# Name: 17, dtype: object
#
#             PLAYER: Aaron Nesmith
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.593994150290162
#                 EV: 0.0913784310585326
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: assists
#             THRESH: 1.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.40600584970983794
#                 EV: -0.9399415029016209
#         HOUSE_PROB: 0.5
#
# Prop object created.
# player_name        Pascal Siakam
# team                      Pacers
# stat                     assists
# over_threshold               2.5
# over_odds                   -160
# under_threshold              2.5
# under_odds                   115
# Name: 18, dtype: object
#
#             PLAYER: Pascal Siakam
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -160
#               TYPE: over
#               PROB: 0.6200962589216268
#                 EV: 0.03828210373821772
#         HOUSE_PROB: 0.6153846153846154
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: assists
#             THRESH: 2.5
#               ODDS: 115
#               TYPE: under
#               PROB: 0.37990374107837316
#                 EV: -0.9160347834074889
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
# player_name        Andrew Nembhard
# team                        Pacers
# stat                       assists
# over_threshold                 4.5
# over_odds                      105
# under_threshold                4.5
# under_odds                    -145
# Name: 19, dtype: object
#
#             PLAYER: Andrew Nembhard
#               STAT: assists
#             THRESH: 4.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.4488161914556842
#                 EV: -0.3996340375792373
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -145
#               TYPE: under
#               PROB: 0.5511838085443158
#                 EV: -0.34344713471181443
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
# player_name        Obi Toppin
# team                   Pacers
# stat                  assists
# over_threshold            1.5
# over_odds                 110
# under_threshold           1.5
# under_odds               -155
# Name: 20, dtype: object
#
#             PLAYER: Obi Toppin
#               STAT: assists
#             THRESH: 1.5
#               ODDS: 110
#               TYPE: over
#               PROB: 0.5251561758483804
#                 EV: 0.5141398464079936
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: assists
#             THRESH: 1.5
#               ODDS: -155
#               TYPE: under
#               PROB: 0.47484382415161963
#                 EV: -1.0940266077850649
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
# player_name        Jaylen Brown
# team                    Celtics
# stat                    assists
# over_threshold              2.5
# over_odds                  -150
# under_threshold             2.5
# under_odds                  105
# Name: 21, dtype: object
#
#             PLAYER: Jaylen Brown
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -150
#               TYPE: over
#               PROB: 0.5305463165333175
#                 EV: -0.5787806955556878
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: Jaylen Brown
#               STAT: assists
#             THRESH: 2.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.4694536834666825
#                 EV: -0.18809974446650468
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
# player_name        Derrick White
# team                     Celtics
# stat                     assists
# over_threshold               4.5
# over_odds                    100
# under_threshold              4.5
# under_odds                  -140
# Name: 22, dtype: object
#
#             PLAYER: Derrick White
#               STAT: assists
#             THRESH: 4.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.580304290724543
#                 EV: 0.8030429072454304
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Derrick White
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -140
#               TYPE: under
#               PROB: 0.419695709275457
#                 EV: -1.4026082062103677
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
# player_name        Jrue Holiday
# team                    Celtics
# stat                    assists
# over_threshold              4.5
# over_odds                  -115
# under_threshold             4.5
# under_odds                 -120
# Name: 23, dtype: object
#
#             PLAYER: Jrue Holiday
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.46409610032608195
#                 EV: -0.6617103665170605
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Jrue Holiday
#               STAT: assists
#             THRESH: 4.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.535903899673918
#                 EV: -0.0875475863224171
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Payton Pritchard
# team                        Celtics
# stat                        assists
# over_threshold                  2.5
# over_odds                      -145
# under_threshold                 2.5
# under_odds                      105
# Name: 24, dtype: object
#
#             PLAYER: Payton Pritchard
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -145
#               TYPE: over
#               PROB: 0.8415674019597683
#                 EV: 2.109793568280802
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Payton Pritchard
#               STAT: assists
#             THRESH: 2.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.15843259804023166
#                 EV: -3.3760658700876256
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
# player_name        Al Horford
# team                  Celtics
# stat                  assists
# over_threshold            2.5
# over_odds                -145
# under_threshold           2.5
# under_odds                105
# Name: 25, dtype: object
#
#             PLAYER: Al Horford
#               STAT: assists
#             THRESH: 2.5
#               ODDS: -145
#               TYPE: over
#               PROB: 0.3449659114003927
#                 EV: -2.085632817479441
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Al Horford
#               STAT: assists
#             THRESH: 2.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.6550340885996073
#                 EV: 1.7140994081459748
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
# player_name        Jayson Tatum
# team                    Celtics
# stat                    assists
# over_threshold              5.5
# over_odds                  -140
# under_threshold             5.5
# under_odds                  100
# Name: 26, dtype: object
#
#             PLAYER: Jayson Tatum
#               STAT: assists
#             THRESH: 5.5
#               ODDS: -140
#               TYPE: over
#               PROB: 0.4607702035968184
#                 EV: -1.05054111202727
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
#
#             PLAYER: Jayson Tatum
#               STAT: assists
#             THRESH: 5.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.5392297964031816
#                 EV: 0.3922979640318154
#         HOUSE_PROB: 0.5
#
# Prop object created.
# player_name        Luke Kornet
# team                   Celtics
# stat                   assists
# over_threshold             0.5
# over_odds                 -115
# under_threshold            0.5
# under_odds                -125
# Name: 27, dtype: object
#
#             PLAYER: Luke Kornet
#               STAT: assists
#             THRESH: 0.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.721962699546806
#                 EV: 1.7487817566331865
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Luke Kornet
#               STAT: assists
#             THRESH: 0.5
#               ODDS: -125
#               TYPE: under
#               PROB: 0.278037300453194
#                 EV: -2.4976642959212536
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
# player_name        Tyrese Haliburton
# team                          Pacers
# stat                            fg3m
# over_threshold                   3.5
# over_odds                       -125
# under_threshold                  3.5
# under_odds                      -115
# Name: 28, dtype: object
#
#             PLAYER: Tyrese Haliburton
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.4240759422180088
#                 EV: -1.1833165200379208
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.5759240577819912
#                 EV: 0.38363793144035263
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
# player_name        Aaron Nesmith
# team                      Pacers
# stat                        fg3m
# over_threshold               1.5
# over_odds                   -115
# under_threshold              1.5
# under_odds                  -120
# Name: 29, dtype: object
#
#             PLAYER: Aaron Nesmith
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.4354585328081444
#                 EV: -0.9294093672282155
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.5645414671918556
#                 EV: 0.17496344925867735
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Myles Turner
# team                     Pacers
# stat                       fg3m
# over_threshold              1.5
# over_odds                  -145
# under_threshold             1.5
# under_odds                  100
# Name: 30, dtype: object
#
#             PLAYER: Myles Turner
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -145
#               TYPE: over
#               PROB: 0.664507801973037
#                 EV: 0.6139452235653131
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.33549219802696295
#                 EV: -1.6450780197303705
#         HOUSE_PROB: 0.5
#
# Prop object created.
# player_name        Pascal Siakam
# team                      Pacers
# stat                        fg3m
# over_threshold               0.5
# over_odds                   -195
# under_threshold              0.5
# under_odds                   135
# Name: 31, dtype: object
#
#             PLAYER: Pascal Siakam
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: -195
#               TYPE: over
#               PROB: 0.5682894765709202
#                 EV: -0.7014001131173986
#         HOUSE_PROB: 0.6610169491525424
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: 135
#               TYPE: under
#               PROB: 0.4317105234290798
#                 EV: 0.07259865029168733
#         HOUSE_PROB: 0.425531914893617
#
# Prop object created.
# player_name        Andrew Nembhard
# team                        Pacers
# stat                          fg3m
# over_threshold                 1.5
# over_odds                      170
# under_threshold                1.5
# under_odds                    -250
# Name: 32, dtype: object
#
#             PLAYER: Andrew Nembhard
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 170
#               TYPE: over
#               PROB: 0.38024609943922716
#                 EV: 0.1333223424295671
#         HOUSE_PROB: 0.37037037037037035
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -250
#               TYPE: under
#               PROB: 0.6197539005607728
#                 EV: -0.6617226960745901
#         HOUSE_PROB: 0.7142857142857143
#
# Prop object created.
# player_name        T.J. McConnell
# team                       Pacers
# stat                         fg3m
# over_threshold                0.5
# over_odds                     195
# under_threshold               0.5
# under_odds                   -300
# Name: 33, dtype: object
#
#             PLAYER: T.J. McConnell
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: 195
#               TYPE: over
#               PROB: 0.38121660819385905
#                 EV: 0.6229449708594208
#         HOUSE_PROB: 0.3389830508474576
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: fg3m
#             THRESH: 0.5
#               ODDS: -300
#               TYPE: under
#               PROB: 0.618783391806141
#                 EV: -0.8747773879590603
#         HOUSE_PROB: 0.75
#
# Prop object created.
# player_name        Obi Toppin
# team                   Pacers
# stat                     fg3m
# over_threshold            1.5
# over_odds                 170
# under_threshold           1.5
# under_odds               -250
# Name: 34, dtype: object
#
#             PLAYER: Obi Toppin
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 170
#               TYPE: over
#               PROB: 0.40816728654014434
#                 EV: 0.5102583682919484
#         HOUSE_PROB: 0.37037037037037035
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -250
#               TYPE: under
#               PROB: 0.5918327134598557
#                 EV: -0.8571710057810105
#         HOUSE_PROB: 0.7142857142857143
#
# Prop object created.
# player_name        Payton Pritchard
# team                        Celtics
# stat                           fg3m
# over_threshold                  1.5
# over_odds                      -125
# under_threshold                 1.5
# under_odds                     -115
# Name: 35, dtype: object
#
#             PLAYER: Payton Pritchard
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.6047127189295851
#                 EV: 0.44241447036626624
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Payton Pritchard
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.39528728107041483
#                 EV: -1.3049232421678614
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
# player_name        Al Horford
# team                  Celtics
# stat                     fg3m
# over_threshold            1.5
# over_odds                -145
# under_threshold           1.5
# under_odds                100
# Name: 36, dtype: object
#
#             PLAYER: Al Horford
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -145
#               TYPE: over
#               PROB: 0.5605404954201741
#                 EV: -0.2643992628295626
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
#
#             PLAYER: Al Horford
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 100
#               TYPE: under
#               PROB: 0.43945950457982585
#                 EV: -0.6054049542017417
#         HOUSE_PROB: 0.5
#
# Prop object created.
# player_name        Jayson Tatum
# team                    Celtics
# stat                       fg3m
# over_threshold              2.5
# over_odds                  -130
# under_threshold             2.5
# under_odds                 -110
# Name: 37, dtype: object
#
#             PLAYER: Jayson Tatum
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: -130
#               TYPE: over
#               PROB: 0.4714829505372484
#                 EV: -0.8291892837089563
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
#
#             PLAYER: Jayson Tatum
#               STAT: fg3m
#             THRESH: 2.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.5285170494627516
#                 EV: 0.04493547214444771
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
# player_name        Jrue Holiday
# team                    Celtics
# stat                       fg3m
# over_threshold              1.5
# over_odds                  -165
# under_threshold             1.5
# under_odds                  115
# Name: 38, dtype: object
#
#             PLAYER: Jrue Holiday
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -165
#               TYPE: over
#               PROB: 0.5251561758483804
#                 EV: -0.7828367697024001
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
#
#             PLAYER: Jrue Holiday
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 115
#               TYPE: under
#               PROB: 0.47484382415161963
#                 EV: 0.10457110962991134
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
# player_name        Derrick White
# team                     Celtics
# stat                        fg3m
# over_threshold               3.5
# over_odds                    115
# under_threshold              3.5
# under_odds                  -165
# Name: 39, dtype: object
#
#             PLAYER: Derrick White
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: 115
#               TYPE: over
#               PROB: 0.4152396303893593
#                 EV: -0.536173973314388
#         HOUSE_PROB: 0.46511627906976744
#
# Prop object created.
#
#             PLAYER: Derrick White
#               STAT: fg3m
#             THRESH: 3.5
#               ODDS: -165
#               TYPE: under
#               PROB: 0.5847603696106407
#                 EV: -0.30419703191455216
#         HOUSE_PROB: 0.6226415094339623
#
# Prop object created.
# player_name        Jaylen Brown
# team                    Celtics
# stat                       fg3m
# over_threshold              1.5
# over_odds                  -190
# under_threshold             1.5
# under_odds                  130
# Name: 40, dtype: object
#
#             PLAYER: Jaylen Brown
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: -190
#               TYPE: over
#               PROB: 0.6152149464283662
#                 EV: -0.3049385667308906
#         HOUSE_PROB: 0.6551724137931035
#
# Prop object created.
#
#             PLAYER: Jaylen Brown
#               STAT: fg3m
#             THRESH: 1.5
#               ODDS: 130
#               TYPE: under
#               PROB: 0.38478505357163384
#                 EV: -0.574971883926211
#         HOUSE_PROB: 0.4347826086956522
#
# Prop object created.
# player_name        Pascal Siakam
# team                      Pacers
# stat                    rebounds
# over_threshold               7.5
# over_odds                   -115
# under_threshold              7.5
# under_odds                  -125
# Name: 41, dtype: object
#
#             PLAYER: Pascal Siakam
#               STAT: rebounds
#             THRESH: 7.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.5358175658470324
#                 EV: 0.008729419874433653
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Pascal Siakam
#               STAT: rebounds
#             THRESH: 7.5
#               ODDS: -125
#               TYPE: under
#               PROB: 0.46418243415296756
#                 EV: -0.8223580926232916
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
# player_name        Tyrese Haliburton
# team                          Pacers
# stat                        rebounds
# over_threshold                   4.5
# over_odds                       -115
# under_threshold                  4.5
# under_odds                      -120
# Name: 42, dtype: object
#
#             PLAYER: Tyrese Haliburton
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -115
#               TYPE: over
#               PROB: 0.46409610032608195
#                 EV: -0.6617103665170605
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
#
#             PLAYER: Tyrese Haliburton
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -120
#               TYPE: under
#               PROB: 0.535903899673918
#                 EV: -0.0875475863224171
#         HOUSE_PROB: 0.5454545454545454
#
# Prop object created.
# player_name        Aaron Nesmith
# team                      Pacers
# stat                    rebounds
# over_threshold               4.5
# over_odds                   -135
# under_threshold              4.5
# under_odds                  -105
# Name: 43, dtype: object
#
#             PLAYER: Aaron Nesmith
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -135
#               TYPE: over
#               PROB: 0.4564712858513804
#                 EV: -1.0270091787009479
#         HOUSE_PROB: 0.574468085106383
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -105
#               TYPE: under
#               PROB: 0.5435287141486196
#                 EV: 0.3058755428793809
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
# player_name        T.J. McConnell
# team                       Pacers
# stat                     rebounds
# over_threshold                2.5
# over_odds                    -125
# under_threshold               2.5
# under_odds                   -110
# Name: 44, dtype: object
#
#             PLAYER: T.J. McConnell
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.4407062483387585
#                 EV: -1.0336437649511736
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -110
#               TYPE: under
#               PROB: 0.5592937516612415
#                 EV: 0.33871308403912437
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
# player_name        Myles Turner
# team                     Pacers
# stat                   rebounds
# over_threshold              6.5
# over_odds                  -155
# under_threshold             6.5
# under_odds                  110
# Name: 45, dtype: object
#
#             PLAYER: Myles Turner
#               STAT: rebounds
#             THRESH: 6.5
#               ODDS: -155
#               TYPE: over
#               PROB: 0.4891605790710861
#                 EV: -0.9762597528023562
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: Myles Turner
#               STAT: rebounds
#             THRESH: 6.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.5108394209289139
#                 EV: 0.36381391975359545
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
# player_name        Andrew Nembhard
# team                        Pacers
# stat                      rebounds
# over_threshold                 2.5
# over_odds                     -150
# under_threshold                2.5
# under_odds                     105
# Name: 46, dtype: object
#
#             PLAYER: Andrew Nembhard
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -150
#               TYPE: over
#               PROB: 0.5400264169946777
#                 EV: -0.49977985837768646
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: 105
#               TYPE: under
#               PROB: 0.4599735830053223
#                 EV: -0.2852707741954461
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
# player_name        Obi Toppin
# team                   Pacers
# stat                 rebounds
# over_threshold            3.5
# over_odds                -155
# under_threshold           3.5
# under_odds                110
# Name: 47, dtype: object
#
#             PLAYER: Obi Toppin
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: -155
#               TYPE: over
#               PROB: 0.5971478702870898
#                 EV: -0.08797719602555176
#         HOUSE_PROB: 0.607843137254902
#
# Prop object created.
#
#             PLAYER: Obi Toppin
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: 110
#               TYPE: under
#               PROB: 0.40285212971291023
#                 EV: -0.7700526380144428
#         HOUSE_PROB: 0.47619047619047616
#
# Prop object created.
# player_name        Payton Pritchard
# team                        Celtics
# stat                       rebounds
# over_threshold                  2.5
# over_odds                      -125
# under_threshold                 2.5
# under_odds                     -115
# Name: 48, dtype: object
#
#             PLAYER: Payton Pritchard
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -125
#               TYPE: over
#               PROB: 0.5857115890686466
#                 EV: 0.27140430161781914
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
#
#             PLAYER: Payton Pritchard
#               STAT: rebounds
#             THRESH: 2.5
#               ODDS: -115
#               TYPE: under
#               PROB: 0.41428841093135343
#                 EV: -1.127303984772131
#         HOUSE_PROB: 0.5348837209302326
#
# Prop object created.
# player_name        Jaylen Brown
# team                    Celtics
# stat                   rebounds
# over_threshold              6.5
# over_odds                  -110
# under_threshold             6.5
# under_odds                 -130
# Name: 49, dtype: object
#
#             PLAYER: Jaylen Brown
#               STAT: rebounds
#             THRESH: 6.5
#               ODDS: -110
#               TYPE: over
#               PROB: 0.4001218586364651
#                 EV: -1.1806549857428328
#         HOUSE_PROB: 0.5238095238095238
#
# Prop object created.
#
#             PLAYER: Jaylen Brown
#               STAT: rebounds
#             THRESH: 6.5
#               ODDS: -130
#               TYPE: under
#               PROB: 0.5998781413635349
#                 EV: 0.3066143274466553
#         HOUSE_PROB: 0.5652173913043479
#
# Prop object created.
# player_name        Al Horford
# team                  Celtics
# stat                 rebounds
# over_threshold            7.5
# over_odds                 100
# under_threshold           7.5
# under_odds               -145
# Name: 50, dtype: object
#
#             PLAYER: Al Horford
#               STAT: rebounds
#             THRESH: 7.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.2839837422078052
#                 EV: -2.160162577921948
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Al Horford
#               STAT: rebounds
#             THRESH: 7.5
#               ODDS: -145
#               TYPE: under
#               PROB: 0.7160162577921948
#                 EV: 1.0491028675547494
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
# player_name        Jayson Tatum
# team                    Celtics
# stat                   rebounds
# over_threshold             10.5
# over_odds                   105
# under_threshold            10.5
# under_odds                 -145
# Name: 51, dtype: object
#
#             PLAYER: Jayson Tatum
#               STAT: rebounds
#             THRESH: 10.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.2170950355584922
#                 EV: -2.774775885525455
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Jayson Tatum
#               STAT: rebounds
#             THRESH: 10.5
#               ODDS: -145
#               TYPE: under
#               PROB: 0.7829049644415078
#                 EV: 1.6141971133851527
#         HOUSE_PROB: 0.5918367346938775
#
# Prop object created.
# player_name        Jrue Holiday
# team                    Celtics
# stat                   rebounds
# over_threshold              5.5
# over_odds                   100
# under_threshold             5.5
# under_odds                 -140
# Name: 52, dtype: object
#
#             PLAYER: Jrue Holiday
#               STAT: rebounds
#             THRESH: 5.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.32808719139847375
#                 EV: -1.7191280860152625
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: Jrue Holiday
#               STAT: rebounds
#             THRESH: 5.5
#               ODDS: -140
#               TYPE: under
#               PROB: 0.6719128086015262
#                 EV: 0.7592526451559403
#         HOUSE_PROB: 0.5833333333333333
#
# Prop object created.
# player_name        Derrick White
# team                     Celtics
# stat                    rebounds
# over_threshold               3.5
# over_odds                   -170
# under_threshold              3.5
# under_odds                   120
# Name: 53, dtype: object
#
#             PLAYER: Derrick White
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: -170
#               TYPE: over
#               PROB: 0.6807710116020809
#                 EV: 0.4061227391929956
#         HOUSE_PROB: 0.6296296296296295
#
# Prop object created.
#
#             PLAYER: Derrick White
#               STAT: rebounds
#             THRESH: 3.5
#               ODDS: 120
#               TYPE: under
#               PROB: 0.31922898839791913
#                 EV: -1.4884811276228893
#         HOUSE_PROB: 0.45454545454545453
#
# Prop object created.
# player_name        Luke Kornet
# team                   Celtics
# stat                  rebounds
# over_threshold             4.5
# over_odds                  105
# under_threshold            4.5
# under_odds                -150
# Name: 54, dtype: object
#
#             PLAYER: Luke Kornet
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: 105
#               TYPE: over
#               PROB: 0.48676599920428576
#                 EV: -0.010648508156070768
#         HOUSE_PROB: 0.48780487804878053
#
# Prop object created.
#
#             PLAYER: Luke Kornet
#               STAT: rebounds
#             THRESH: 4.5
#               ODDS: -150
#               TYPE: under
#               PROB: 0.5132340007957142
#                 EV: -0.7230499933690488
#         HOUSE_PROB: 0.6000000000000001
#
# Prop object created.
# player_name        Andrew Nembhard
# team                        Pacers
# stat                           fgm
# over_threshold                 4.5
# over_odds                     -105
# under_threshold                4.5
# under_odds                    -125
# Name: 55, dtype: object
#
#             PLAYER: Andrew Nembhard
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: -105
#               TYPE: over
#               PROB: 0.516436108538427
#                 EV: 0.0414001071608352
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Andrew Nembhard
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: -125
#               TYPE: under
#               PROB: 0.48356389146157297
#                 EV: -0.647924976845843
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
# player_name        Aaron Nesmith
# team                      Pacers
# stat                         fgm
# over_threshold               3.5
# over_odds                   -105
# under_threshold              3.5
# under_odds                  -125
# Name: 56, dtype: object
#
#             PLAYER: Aaron Nesmith
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -105
#               TYPE: over
#               PROB: 0.5346638747764247
#                 EV: 0.2193378251984317
#         HOUSE_PROB: 0.5121951219512195
#
# Prop object created.
#
#             PLAYER: Aaron Nesmith
#               STAT: fgm
#             THRESH: 3.5
#               ODDS: -125
#               TYPE: under
#               PROB: 0.46533612522357526
#                 EV: -0.8119748729878227
#         HOUSE_PROB: 0.5555555555555556
#
# Prop object created.
# player_name        T.J. McConnell
# team                       Pacers
# stat                          fgm
# over_threshold                4.5
# over_odds                     100
# under_threshold               4.5
# under_odds                   -130
# Name: 57, dtype: object
#
#             PLAYER: T.J. McConnell
#               STAT: fgm
#             THRESH: 4.5
#               ODDS: 100
#               TYPE: over
#               PROB: 0.6872816501433185
#                 EV: 1.872816501433185
#         HOUSE_PROB: 0.5
#
# Prop object created.
#
#             PLAYER: T.J. McConnell
#               STAT: fgm
# ...
#
#    HOUSE_PROB
# 0    0.565217
# 1    0.512195
# 2    0.583333
#
# Combination 5820:
#           PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0    Luke Kornet  Celtics     fgm     1.5  -130   over  0.625501  0.533281
# 1  Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
# 2   Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.565217
# 1    0.545455
# 2    0.583333
#
# Combination 5821:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers   assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics    steals     0.5  -155  under  0.618783
# 2      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.089992    0.607843
# 2  0.306614    0.565217
#
# Combination 5822:
#              PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics   steals     0.5  -155  under  0.618783
# 2      Jrue Holiday  Celtics      fgm     4.5   100  under  0.597611
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.089992    0.607843
# 2  0.976109    0.500000
#
# Combination 5823:
#              PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics   steals     0.5  -155  under  0.618783
# 2     Aaron Nesmith   Pacers   steals     0.5  -120  under  0.594521
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.089992    0.607843
# 2  0.449772    0.545455
#
# Combination 5824:
#              PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics   steals     0.5  -155  under  0.618783
# 2      Jaylen Brown  Celtics   blocks     0.5  -140  under  0.594521
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.089992    0.607843
# 2  0.095890    0.583333
#
# Combination 5825:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers   assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics      fg3m     1.5  -125   over  0.604713
# 2      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.442414    0.555556
# 2  0.306614    0.565217
#
# Combination 5826:
#              PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics     fg3m     1.5  -125   over  0.604713
# 2      Jrue Holiday  Celtics      fgm     4.5   100  under  0.597611
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.442414    0.555556
# 2  0.976109    0.500000
#
# Combination 5827:
#              PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics     fg3m     1.5  -125   over  0.604713
# 2     Aaron Nesmith   Pacers   steals     0.5  -120  under  0.594521
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.442414    0.555556
# 2  0.449772    0.545455
#
# Combination 5828:
#              PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB  \
# 0     Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096
# 1  Payton Pritchard  Celtics     fg3m     1.5  -125   over  0.604713
# 2      Jaylen Brown  Celtics   blocks     0.5  -140  under  0.594521
#
#          EV  HOUSE_PROB
# 0  0.038282    0.615385
# 1  0.442414    0.555556
# 2  0.095890    0.583333
#
# Combination 5829:
#           PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Pascal Siakam   Pacers   assists     2.5  -160   over  0.620096  0.038282
# 1   Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878  0.306614
# 2   Jrue Holiday  Celtics       fgm     4.5   100  under  0.597611  0.976109
#
#    HOUSE_PROB
# 0    0.615385
# 1    0.565217
# 2    0.500000
#
# Combination 5830:
#           PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Pascal Siakam   Pacers   assists     2.5  -160   over  0.620096  0.038282
# 1   Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878  0.306614
# 2  Aaron Nesmith   Pacers    steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.615385
# 1    0.565217
# 2    0.545455
#
# Combination 5831:
#           PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096  0.038282
# 1   Jrue Holiday  Celtics      fgm     4.5   100  under  0.597611  0.976109
# 2  Aaron Nesmith   Pacers   steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.615385
# 1    0.500000
# 2    0.545455
#
# Combination 5832:
#           PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096  0.038282
# 1   Jrue Holiday  Celtics      fgm     4.5   100  under  0.597611  0.976109
# 2   Jaylen Brown  Celtics   blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.615385
# 1    0.500000
# 2    0.583333
#
# Combination 5833:
#           PLAYER     TEAM     STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Pascal Siakam   Pacers  assists     2.5  -160   over  0.620096  0.038282
# 1  Aaron Nesmith   Pacers   steals     0.5  -120  under  0.594521  0.449772
# 2   Jaylen Brown  Celtics   blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.615385
# 1    0.545455
# 2    0.583333
#
# Combination 5834:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0  Payton Pritchard  Celtics    steals     0.5  -155  under  0.618783
# 1      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
# 2      Jrue Holiday  Celtics       fgm     4.5   100  under  0.597611
#
#          EV  HOUSE_PROB
# 0  0.089992    0.607843
# 1  0.306614    0.565217
# 2  0.976109    0.500000
#
# Combination 5835:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0  Payton Pritchard  Celtics    steals     0.5  -155  under  0.618783
# 1      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
# 2     Pascal Siakam   Pacers    points    20.5  -105   over  0.596771
#
#          EV  HOUSE_PROB
# 0  0.089992    0.607843
# 1  0.306614    0.565217
# 2  0.825626    0.512195
#
# Combination 5836:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0  Payton Pritchard  Celtics    steals     0.5  -155  under  0.618783
# 1      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
# 2     Aaron Nesmith   Pacers    steals     0.5  -120  under  0.594521
#
#          EV  HOUSE_PROB
# 0  0.089992    0.607843
# 1  0.306614    0.565217
# 2  0.449772    0.545455
#
# Combination 5837:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics  steals     0.5  -155  under  0.618783  0.089992
# 1      Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 2     Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
#
#    HOUSE_PROB
# 0    0.607843
# 1    0.500000
# 2    0.512195
#
# Combination 5838:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics  steals     0.5  -155  under  0.618783  0.089992
# 1      Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 2     Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.607843
# 1    0.500000
# 2    0.545455
#
# Combination 5839:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics  steals     0.5  -155  under  0.618783  0.089992
# 1      Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 2      Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.607843
# 1    0.500000
# 2    0.583333
#
# Combination 5840:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics  steals     0.5  -155  under  0.618783  0.089992
# 1     Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 2     Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.607843
# 1    0.512195
# 2    0.545455
#
# Combination 5841:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics  steals     0.5  -155  under  0.618783  0.089992
# 1     Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 2      Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.607843
# 1    0.512195
# 2    0.583333
#
# Combination 5842:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics  steals     0.5  -155  under  0.618783  0.089992
# 1     Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
# 2      Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.607843
# 1    0.545455
# 2    0.583333
#
# Combination 5843:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0  Payton Pritchard  Celtics      fg3m     1.5  -125   over  0.604713
# 1      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
# 2      Jrue Holiday  Celtics       fgm     4.5   100  under  0.597611
#
#          EV  HOUSE_PROB
# 0  0.442414    0.555556
# 1  0.306614    0.565217
# 2  0.976109    0.500000
#
# Combination 5844:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0  Payton Pritchard  Celtics      fg3m     1.5  -125   over  0.604713
# 1      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
# 2     Pascal Siakam   Pacers    points    20.5  -105   over  0.596771
#
#          EV  HOUSE_PROB
# 0  0.442414    0.555556
# 1  0.306614    0.565217
# 2  0.825626    0.512195
#
# Combination 5845:
#              PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB  \
# 0  Payton Pritchard  Celtics      fg3m     1.5  -125   over  0.604713
# 1      Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878
# 2     Aaron Nesmith   Pacers    steals     0.5  -120  under  0.594521
#
#          EV  HOUSE_PROB
# 0  0.442414    0.555556
# 1  0.306614    0.565217
# 2  0.449772    0.545455
#
# Combination 5846:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics    fg3m     1.5  -125   over  0.604713  0.442414
# 1      Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 2     Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
#
#    HOUSE_PROB
# 0    0.555556
# 1    0.500000
# 2    0.512195
#
# Combination 5847:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics    fg3m     1.5  -125   over  0.604713  0.442414
# 1      Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 2     Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.555556
# 1    0.500000
# 2    0.545455
#
# Combination 5848:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics    fg3m     1.5  -125   over  0.604713  0.442414
# 1      Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 2      Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.555556
# 1    0.500000
# 2    0.583333
#
# Combination 5849:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics    fg3m     1.5  -125   over  0.604713  0.442414
# 1     Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 2     Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.555556
# 1    0.512195
# 2    0.545455
#
# Combination 5850:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics    fg3m     1.5  -125   over  0.604713  0.442414
# 1     Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 2      Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.555556
# 1    0.512195
# 2    0.583333
#
# Combination 5851:
#              PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Payton Pritchard  Celtics    fg3m     1.5  -125   over  0.604713  0.442414
# 1     Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
# 2      Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.555556
# 1    0.545455
# 2    0.583333
#
# Combination 5852:
#           PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0   Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878  0.306614
# 1   Jrue Holiday  Celtics       fgm     4.5   100  under  0.597611  0.976109
# 2  Pascal Siakam   Pacers    points    20.5  -105   over  0.596771  0.825626
#
#    HOUSE_PROB
# 0    0.565217
# 1    0.500000
# 2    0.512195
#
# Combination 5853:
#           PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0   Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878  0.306614
# 1   Jrue Holiday  Celtics       fgm     4.5   100  under  0.597611  0.976109
# 2  Aaron Nesmith   Pacers    steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.565217
# 1    0.500000
# 2    0.545455
#
# Combination 5854:
#           PLAYER     TEAM      STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0   Jaylen Brown  Celtics  rebounds     6.5  -130  under  0.599878  0.306614
# 1  Pascal Siakam   Pacers    points    20.5  -105   over  0.596771  0.825626
# 2  Aaron Nesmith   Pacers    steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.565217
# 1    0.512195
# 2    0.545455
#
# Combination 5855:
#           PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0   Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 1  Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 2  Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
#
#    HOUSE_PROB
# 0    0.500000
# 1    0.512195
# 2    0.545455
#
# Combination 5856:
#           PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0   Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 1  Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 2   Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.500000
# 1    0.512195
# 2    0.583333
#
# Combination 5857:
#           PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0   Jrue Holiday  Celtics     fgm     4.5   100  under  0.597611  0.976109
# 1  Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
# 2   Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.500000
# 1    0.545455
# 2    0.583333
#
# Combination 5858:
#           PLAYER     TEAM    STAT  THRESH  ODDS   TYPE      PROB        EV  \
# 0  Pascal Siakam   Pacers  points    20.5  -105   over  0.596771  0.825626
# 1  Aaron Nesmith   Pacers  steals     0.5  -120  under  0.594521  0.449772
# 2   Jaylen Brown  Celtics  blocks     0.5  -140  under  0.594521  0.095890
#
#    HOUSE_PROB
# 0    0.512195
# 1    0.545455
# 2    0.583333

# %%
candidates = []
for i, df in enumerate(combo_dfs):
    
    today = date.today()
    
    probs = list(df['PROB'])
    odds = [odds for odds in list(df['ODDS'])]
    combined_ev, potential_winnings = analyze.analyze_parlay(probs, odds, 1)
    combined_prob = analyze.calculate_combined_probability(probs)
    df['COMBINED EV'] = combined_ev
    df['COMBINED PROB'] = combined_prob
    df['TO WIN'] = potential_winnings

    parlay_tag = f"{today}_{i}_"
    candidate = [parlay_tag]
    props = []
    for _, row in df.iterrows():
        prop_info = f"{row['PLAYER']}_{row['STAT']}_{row['THRESH']}_{row['ODDS']}_{row['TYPE']}_P{row['PROB']:.3f}_EV{row['EV']:.3f}_HOUSE_PROV{row['HOUSE_PROB']:.3f}"
        props.append(prop_info)
    candidate.append(" + ".join(props))
    candidate += [combined_prob, combined_ev, potential_winnings]
    candidates.append(candidate)
# Out:
# Combined Probability: 0.6181
# Combined Odds: 3.48
# Expected Value (EV): $1.15
# Potential Winnings: $3.48
# Combined Probability: 0.6146
# Combined Odds: 3.85
# Expected Value (EV): $1.36
# Potential Winnings: $3.85
# Combined Probability: 0.5964
# Combined Odds: 3.53
# Expected Value (EV): $1.10
# Potential Winnings: $3.53
# Combined Probability: 0.5750
# Combined Odds: 3.48
# Expected Value (EV): $1.00
# Potential Winnings: $3.48
# Combined Probability: 0.5707
# Combined Odds: 3.23
# Expected Value (EV): $0.85
# Potential Winnings: $3.23
# Combined Probability: 0.5649
# Combined Odds: 3.77
# Expected Value (EV): $1.13
# Potential Winnings: $3.77
# Combined Probability: 0.5479
# Combined Odds: 3.77
# Expected Value (EV): $1.07
# Potential Winnings: $3.77
# Combined Probability: 0.5434
# Combined Odds: 3.77
# Expected Value (EV): $1.05
# Potential Winnings: $3.77
# Combined Probability: 0.5404
# Combined Odds: 2.88
# Expected Value (EV): $0.56
# Potential Winnings: $2.88
# Combined Probability: 0.5303
# Combined Odds: 3.85
# Expected Value (EV): $1.04
# Potential Winnings: $3.85
# Combined Probability: 0.5296
# Combined Odds: 3.11
# Expected Value (EV): $0.65
# Potential Winnings: $3.11
# Combined Probability: 0.5259
# Combined Odds: 3.48
# Expected Value (EV): $0.83
# Potential Winnings: $3.48
# Combined Probability: 0.5048
# Combined Odds: 4.11
# Expected Value (EV): $1.08
# Potential Winnings: $4.11
# Combined Probability: 0.5048
# Combined Odds: 3.58
# Expected Value (EV): $0.81
# Potential Winnings: $3.58
# Combined Probability: 0.5000
# Combined Odds: 3.27
# Expected Value (EV): $0.63
# Potential Winnings: $3.27
# Combined Probability: 0.4935
# Combined Odds: 3.53
# Expected Value (EV): $0.74
# Potential Winnings: $3.53
# Combined Probability: 0.4923
# Combined Odds: 3.14
# Expected Value (EV): $0.55
# Potential Winnings: $3.14
# Combined Probability: 0.4923
# Combined Odds: 3.70
# Expected Value (EV): $0.82
# Potential Winnings: $3.70
# Combined Probability: 0.4881
# Combined Odds: 3.48
# Expected Value (EV): $0.70
# Potential Winnings: $3.48
# Combined Probability: 0.4815
# Combined Odds: 4.02
# Expected Value (EV): $0.93
# Potential Winnings: $4.02
# Combined Probability: 0.4812
# Combined Odds: 3.77
# Expected Value (EV): $0.81
# Potential Winnings: $3.77
# Combined Probability: 0.4811
# Combined Odds: 4.22
# Expected Value (EV): $1.03
# Potential Winnings: $4.22
# Combined Probability: 0.4616
# Combined Odds: 3.70
# Expected Value (EV): $0.71
# Potential Winnings: $3.70
# Combined Probability: 0.4594
# Combined Odds: 3.64
# Expected Value (EV): $0.67
# Potential Winnings: $3.64
# Combined Probability: 0.4554
# Combined Odds: 3.34
# Expected Value (EV): $0.52
# Potential Winnings: $3.34
# Combined Probability: 0.4545
# Combined Odds: 3.38
# Expected Value (EV): $0.54
# Potential Winnings: $3.38
# Combined Probability: 0.4441
# Combined Odds: 3.70
# Expected Value (EV): $0.64
# Potential Winnings: $3.70
# Combined Probability: 0.4406
# Combined Odds: 3.64
# Expected Value (EV): $0.60
# Potential Winnings: $3.64
# Combined Probability: 0.4389
# Combined Odds: 4.11
# Expected Value (EV): $0.81
# Potential Winnings: $4.11
# Combined Probability: 0.4383
# Combined Odds: 4.02
# Expected Value (EV): $0.76
# Potential Winnings: $4.02
# Combined Probability: 0.4367
# Combined Odds: 3.77
# Expected Value (EV): $0.65
# Potential Winnings: $3.77
# Combined Probability: 0.4367
# Combined Odds: 3.53
# Expected Value (EV): $0.54
# Potential Winnings: $3.53
# Combined Probability: 0.5890
# Combined Odds: 5.04
# Expected Value (EV): $1.97
# Potential Winnings: $5.04
# Combined Probability: 0.5679
# Combined Odds: 4.97
# Expected Value (EV): $1.82
# Potential Winnings: $4.97
# Combined Probability: 0.5636
# Combined Odds: 4.62
# Expected Value (EV): $1.61
# Potential Winnings: $4.62
# Combined Probability: 0.5579
# Combined Odds: 5.39
# Expected Value (EV): $2.01
# Potential Winnings: $5.39
# Combined Probability: 0.5367
# Combined Odds: 5.39
# Expected Value (EV): $1.89
# Potential Winnings: $5.39
# Combined Probability: 0.5337
# Combined Odds: 4.12
# Expected Value (EV): $1.20
# Potential Winnings: $4.12
# Combined Probability: 0.5237
# Combined Odds: 5.50
# Expected Value (EV): $1.88
# Potential Winnings: $5.50
# Combined Probability: 0.5230
# Combined Odds: 4.45
# Expected Value (EV): $1.33
# Potential Winnings: $4.45
# Combined Probability: 0.5194
# Combined Odds: 4.97
# Expected Value (EV): $1.58
# Potential Winnings: $4.97
# Combined Probability: 0.4985
# Combined Odds: 5.88
# Expected Value (EV): $1.93
# Potential Winnings: $5.88
# Combined Probability: 0.4985
# Combined Odds: 5.12
# Expected Value (EV): $1.55
# Potential Winnings: $5.12
# Combined Probability: 0.4938
# Combined Odds: 4.67
# Expected Value (EV): $1.31
# Potential Winnings: $4.67
# Combined Probability: 0.4874
# Combined Odds: 5.04
# Expected Value (EV): $1.46
# Potential Winnings: $5.04
# Combined Probability: 0.4862
# Combined Odds: 4.49
# Expected Value (EV): $1.18
# Potential Winnings: $4.49
# Combined Probability: 0.4862
# Combined Odds: 5.29
# Expected Value (EV): $1.57
# Potential Winnings: $5.29
# Combined Probability: 0.4820
# Combined Odds: 4.97
# Expected Value (EV): $1.40
# Potential Winnings: $4.97
# Combined Probability: 0.4755
# Combined Odds: 5.74
# Expected Value (EV): $1.73
# Potential Winnings: $5.74
# Combined Probability: 0.4752
# Combined Odds: 5.39
# Expected Value (EV): $1.56
# Potential Winnings: $5.39
# Combined Probability: 0.4751
# Combined Odds: 6.03
# Expected Value (EV): $1.86
# Potential Winnings: $6.03
# Combined Probability: 0.4559
# Combined Odds: 5.29
# Expected Value (EV): $1.41
# Potential Winnings: $5.29
# Combined Probability: 0.4549
# Combined Odds: 5.20
# Expected Value (EV): $1.37
# Potential Winnings: $5.20
# Combined Probability: 0.4537
# Combined Odds: 5.20
# Expected Value (EV): $1.36
# Potential Winnings: $5.20
# Combined Probability: 0.4498
# Combined Odds: 4.78
# Expected Value (EV): $1.15
# Potential Winnings: $4.78
# Combined Probability: 0.4351
# Combined Odds: 5.20
# Expected Value (EV): $1.26
# Potential Winnings: $5.20
# Combined Probability: 0.4335
# Combined Odds: 5.88
# Expected Value (EV): $1.55
# Potential Winnings: $5.88
# Combined Probability: 0.4329
# Combined Odds: 5.74
# Expected Value (EV): $1.49
# Potential Winnings: $5.74
# Combined Probability: 0.4312
# Combined Odds: 5.39
# Expected Value (EV): $1.33
# Potential Winnings: $5.39
# Combined Probability: 0.4312
# Combined Odds: 5.04
# Expected Value (EV): $1.17
# Potential Winnings: $5.04
# Combined Probability: 0.5857
# Combined Odds: 5.58
# Expected Value (EV): $2.27
# Potential Winnings: $5.58
# Combined Probability: 0.5647
# Combined Odds: 5.50
# Expected Value (EV): $2.11
# Potential Winnings: $5.50
# Combined Probability: 0.5605
# Combined Odds: 5.11
# Expected Value (EV): $1.87
# Potential Winnings: $5.11
# Combined Probability: 0.5548
# Combined Odds: 5.97
# Expected Value (EV): $2.31
# Potential Winnings: $5.97
# Combined Probability: 0.5337
# Combined Odds: 5.97
# Expected Value (EV): $2.18
# Potential Winnings: $5.97
# Combined Probability: 0.5307
# Combined Odds: 4.56
# Expected Value (EV): $1.42
# Potential Winnings: $4.56
# Combined Probability: 0.5207
# Combined Odds: 6.08
# Expected Value (EV): $2.17
# Potential Winnings: $6.08
# Combined Probability: 0.5201
# Combined Odds: 4.92
# Expected Value (EV): $1.56
# Potential Winnings: $4.92
# Combined Probability: 0.5164
# Combined Odds: 5.50
# Expected Value (EV): $1.84
# Potential Winnings: $5.50
# Combined Probability: 0.4957
# Combined Odds: 6.51
# Expected Value (EV): $2.23
# Potential Winnings: $6.51
# Combined Probability: 0.4957
# Combined Odds: 5.67
# Expected Value (EV): $1.81
# Potential Winnings: $5.67
# Combined Probability: 0.4910
# Combined Odds: 5.17
# Expected Value (EV): $1.54
# Potential Winnings: $5.17
# Combined Probability: 0.4846
# Combined Odds: 5.58
# Expected Value (EV): $1.70
# Potential Winnings: $5.58
# Combined Probability: 0.4835
# Combined Odds: 4.97
# Expected Value (EV): $1.40
# Potential Winnings: $4.97
# Combined Probability: 0.4835
# Combined Odds: 5.86
# Expected Value (EV): $1.83
# Potential Winnings: $5.86
# Combined Probability: 0.4793
# Combined Odds: 5.50
# Expected Value (EV): $1.64
# Potential Winnings: $5.50
# Combined Probability: 0.4728
# Combined Odds: 6.35
# Expected Value (EV): $2.00
# Potential Winnings: $6.35
# Combined Probability: 0.4725
# Combined Odds: 5.97
# Expected Value (EV): $1.82
# Potential Winnings: $5.97
# Combined Probability: 0.4724
# Combined Odds: 6.67
# Expected Value (EV): $2.15
# Potential Winnings: $6.67
# Combined Probability: 0.4533
# Combined Odds: 5.86
# Expected Value (EV): $1.66
# Potential Winnings: $5.86
# Combined Probability: 0.4523
# Combined Odds: 5.76
# Expected Value (EV): $1.60
# Potential Winnings: $5.76
# Combined Probability: 0.4511
# Combined Odds: 5.76
# Expected Value (EV): $1.60
# Potential Winnings: $5.76
# Combined Probability: 0.4472
# Combined Odds: 5.29
# Expected Value (EV): $1.37
# Potential Winnings: $5.29
# Combined Probability: 0.4327
# Combined Odds: 5.76
# Expected Value (EV): $1.49
# Potential Winnings: $5.76
# Combined Probability: 0.4310
# Combined Odds: 6.51
# Expected Value (EV): $1.81
# Potential Winnings: $6.51
# Combined Probability: 0.4304
# Combined Odds: 6.35
# Expected Value (EV): $1.73
# Potential Winnings: $6.35
# Combined Probability: 0.4288
# Combined Odds: 5.97
# Expected Value (EV): $1.56
# Potential Winnings: $5.97
# Combined Probability: 0.4288
# Combined Odds: 5.58
# Expected Value (EV): $1.39
# Potential Winnings: $5.58
# Combined Probability: 0.5479
# Combined Odds: 5.04
# Expected Value (EV): $1.76
# Potential Winnings: $5.04
# Combined Probability: 0.5438
# Combined Odds: 4.69
# Expected Value (EV): $1.55
# Potential Winnings: $4.69
# Combined Probability: 0.5383
# Combined Odds: 5.47
# Expected Value (EV): $1.95
# Potential Winnings: $5.47
# Combined Probability: 0.5221
# Combined Odds: 5.47
# Expected Value (EV): $1.86
# Potential Winnings: $5.47
# Combined Probability: 0.5178
# Combined Odds: 5.47
# Expected Value (EV): $1.83
# Potential Winnings: $5.47
# Combined Probability: 0.5149
# Combined Odds: 4.18
# Expected Value (EV): $1.15
# Potential Winnings: $4.18
# Combined Probability: 0.5053
# Combined Odds: 5.58
# Expected Value (EV): $1.82
# Potential Winnings: $5.58
# Combined Probability: 0.5046
# Combined Odds: 4.51
# Expected Value (EV): $1.28
# Potential Winnings: $4.51
# Combined Probability: 0.5011
# Combined Odds: 5.04
# Expected Value (EV): $1.53
# Potential Winnings: $5.04
# Combined Probability: 0.4764
# Combined Odds: 4.74
# Expected Value (EV): $1.26
# Potential Winnings: $4.74
# Combined Probability: 0.4702
# Combined Odds: 5.12
# Expected Value (EV): $1.41
# Potential Winnings: $5.12
# Combined Probability: 0.4691
# Combined Odds: 4.55
# Expected Value (EV): $1.14
# Potential Winnings: $4.55
# Combined Probability: 0.4691
# Combined Odds: 5.37
# Expected Value (EV): $1.52
# Potential Winnings: $5.37
# Combined Probability: 0.4651
# Combined Odds: 5.04
# Expected Value (EV): $1.34
# Potential Winnings: $5.04
# Combined Probability: 0.4588
# Combined Odds: 5.83
# Expected Value (EV): $1.67
# Potential Winnings: $5.83
# Combined Probability: 0.4585
# Combined Odds: 5.47
# Expected Value (EV): $1.51
# Potential Winnings: $5.47
# Combined Probability: 0.4584
# Combined Odds: 6.12
# Expected Value (EV): $1.80
# Potential Winnings: $6.12
# Combined Probability: 0.4399
# Combined Odds: 5.37
# Expected Value (EV): $1.36
# Potential Winnings: $5.37
# Combined Probability: 0.4389
# Combined Odds: 5.28
# Expected Value (EV): $1.32
# Potential Winnings: $5.28
# Combined Probability: 0.4378
# Combined Odds: 5.28
# Expected Value (EV): $1.31
# Potential Winnings: $5.28
# Combined Probability: 0.4340
# Combined Odds: 4.85
# Expected Value (EV): $1.10
# Potential Winnings: $4.85
# Combined Probability: 0.4331
# Combined Odds: 4.91
# Expected Value (EV): $1.13
# Potential Winnings: $4.91
# Combined Probability: 0.4232
# Combined Odds: 5.37
# Expected Value (EV): $1.27
# Potential Winnings: $5.37
# Combined Probability: 0.4198
# Combined Odds: 5.28
# Expected Value (EV): $1.22
# Potential Winnings: $5.28
# Combined Probability: 0.4182
# Combined Odds: 5.97
# Expected Value (EV): $1.50
# Potential Winnings: $5.97
# Combined Probability: 0.4177
# Combined Odds: 5.83
# Expected Value (EV): $1.43
# Potential Winnings: $5.83
# Combined Probability: 0.4161
# Combined Odds: 5.47
# Expected Value (EV): $1.28
# Potential Winnings: $5.47
# Combined Probability: 0.4161
# Combined Odds: 5.12
# Expected Value (EV): $1.13
# Potential Winnings: $5.12
# Combined Probability: 0.5243
# Combined Odds: 4.62
# Expected Value (EV): $1.42
# Potential Winnings: $4.62
# Combined Probability: 0.5034
# Combined Odds: 5.39
# Expected Value (EV): $1.71
# Potential Winnings: $5.39
# Combined Probability: 0.4993
# Combined Odds: 5.39
# Expected Value (EV): $1.69
# Potential Winnings: $5.39
# Combined Probability: 0.4872
# Combined Odds: 5.50
# Expected Value (EV): $1.68
# Potential Winnings: $5.50
# Combined Probability: 0.4866
# Combined Odds: 4.45
# Expected Value (EV): $1.16
# Potential Winnings: $4.45
# Combined Probability: 0.4832
# Combined Odds: 4.97
# Expected Value (EV): $1.40
# Potential Winnings: $4.97
# Combined Probability: 0.4638
# Combined Odds: 5.88
# Expected Value (EV): $1.73
# Potential Winnings: $5.88
# Combined Probability: 0.4638
# Combined Odds: 5.12
# Expected Value (EV): $1.37
# Potential Winnings: $5.12
# Combined Probability: 0.4594
# Combined Odds: 4.67
# Expected Value (EV): $1.15
# Potential Winnings: $4.67
# Combined Probability: 0.4534
# Combined Odds: 5.04
# Expected Value (EV): $1.29
# Potential Winnings: $5.04
# Combined Probability: 0.4523
# Combined Odds: 4.49
# Expected Value (EV): $1.03
# Potential Winnings: $4.49
# Combined Probability: 0.4523
# Combined Odds: 5.29
# Expected Value (EV): $1.39
# Potential Winnings: $5.29
# Combined Probability: 0.4484
# Combined Odds: 4.97
# Expected Value (EV): $1.23
# Potential Winnings: $4.97
# Combined Probability: 0.4421
# Combined Odds: 5.39
# Expected Value (EV): $1.38
# Potential Winnings: $5.39
# Combined Probability: 0.4420
# Combined Odds: 6.03
# Expected Value (EV): $1.67
# Potential Winnings: $6.03
# Combined Probability: 0.4241
# Combined Odds: 5.29
# Expected Value (EV): $1.25
# Potential Winnings: $5.29
# Combined Probability: 0.4232
# Combined Odds: 5.20
# Expected Value (EV): $1.20
# Potential Winnings: $5.20
# Combined Probability: 0.4221
# Combined Odds: 5.20
# Expected Value (EV): $1.20
# Potential Winnings: $5.20
# Combined Probability: 0.4184
# Combined Odds: 4.78
# Expected Value (EV): $1.00
# Potential Winnings: $4.78
# Combined Probability: 0.4175
# Combined Odds: 4.84
# Expected Value (EV): $1.02
# Potential Winnings: $4.84
# Combined Probability: 0.4081
# Combined Odds: 5.29
# Expected Value (EV): $1.16
# Potential Winnings: $5.29
# Combined Probability: 0.4048
# Combined Odds: 5.20
# Expected Value (EV): $1.11
# Potential Winnings: $5.20
# Combined Probability: 0.4033
# Combined Odds: 5.88
# Expected Value (EV): $1.37
# Potential Winnings: $5.88
# Combined Probability: 0.4027
# Combined Odds: 5.74
# Expected Value (EV): $1.31
# Potential Winnings: $5.74
# Combined Probability: 0.4012
# Combined Odds: 5.39
# Expected Value (EV): $1.16
# Potential Winnings: $5.39
# Combined Probability: 0.4012
# Combined Odds: 5.04
# Expected Value (EV): $1.02
# Potential Winnings: $5.04
# Combined Probability: 0.5151
# Combined Odds: 5.01
# Expected Value (EV): $1.58
# Potential Winnings: $5.01
# Combined Probability: 0.4996
# Combined Odds: 5.01
# Expected Value (EV): $1.51
# Potential Winnings: $5.01
# Combined Probability: 0.4955
# Combined Odds: 5.01
# Expected Value (EV): $1.49
# Potential Winnings: $5.01
# Combined Probability: 0.4928
# Combined Odds: 3.83
# Expected Value (EV): $0.89
# Potential Winnings: $3.83
# Combined Probability: 0.4829
# Combined Odds: 4.14
# Expected Value (EV): $1.00
# Potential Winnings: $4.14
# Combined Probability: 0.4795
# Combined Odds: 4.62
# Expected Value (EV): $1.22
# Potential Winnings: $4.62
# Combined Probability: 0.4603
# Combined Odds: 5.47
# Expected Value (EV): $1.52
# Potential Winnings: $5.47
# Combined Probability: 0.4603
# Combined Odds: 4.76
# Expected Value (EV): $1.19
# Potential Winnings: $4.76
# Combined Probability: 0.4559
# Combined Odds: 4.34
# Expected Value (EV): $0.98
# Potential Winnings: $4.34
# Combined Probability: 0.4500
# Combined Odds: 4.69
# Expected Value (EV): $1.11
# Potential Winnings: $4.69
# Combined Probability: 0.4489
# Combined Odds: 4.18
# Expected Value (EV): $0.87
# Potential Winnings: $4.18
# Combined Probability: 0.4489
# Combined Odds: 4.92
# Expected Value (EV): $1.21
# Potential Winnings: $4.92
# Combined Probability: 0.4451
# Combined Odds: 4.62
# Expected Value (EV): $1.06
# Potential Winnings: $4.62
# Combined Probability: 0.4391
# Combined Odds: 5.34
# Expected Value (EV): $1.34
# Potential Winnings: $5.34
# Combined Probability: 0.4388
# Combined Odds: 5.01
# Expected Value (EV): $1.20
# Potential Winnings: $5.01
# Combined Probability: 0.4387
# Combined Odds: 5.61
# Expected Value (EV): $1.46
# Potential Winnings: $5.61
# Combined Probability: 0.4210
# Combined Odds: 4.92
# Expected Value (EV): $1.07
# Potential Winnings: $4.92
# Combined Probability: 0.4200
# Combined Odds: 4.84
# Expected Value (EV): $1.03
# Potential Winnings: $4.84
# Combined Probability: 0.4153
# Combined Odds: 4.45
# Expected Value (EV): $0.85
# Potential Winnings: $4.45
# Combined Probability: 0.4144
# Combined Odds: 4.50
# Expected Value (EV): $0.87
# Potential Winnings: $4.50
# Combined Probability: 0.4050
# Combined Odds: 4.92
# Expected Value (EV): $0.99
# Potential Winnings: $4.92
# Combined Probability: 0.4018
# Combined Odds: 4.84
# Expected Value (EV): $0.94
# Potential Winnings: $4.84
# Combined Probability: 0.4002
# Combined Odds: 5.47
# Expected Value (EV): $1.19
# Potential Winnings: $5.47
# Combined Probability: 0.3997
# Combined Odds: 5.34
# Expected Value (EV): $1.13
# Potential Winnings: $5.34
# Combined Probability: 0.3982
# Combined Odds: 5.01
# Expected Value (EV): $1.00
# Potential Winnings: $5.01
# Combined Probability: 0.3982
# Combined Odds: 4.69
# Expected Value (EV): $0.87
# Potential Winnings: $4.69
# Combined Probability: 0.4946
# Combined Odds: 5.85
# Expected Value (EV): $1.89
# Potential Winnings: $5.85
# Combined Probability: 0.4905
# Combined Odds: 5.85
# Expected Value (EV): $1.87
# Potential Winnings: $5.85
# Combined Probability: 0.4786
# Combined Odds: 5.97
# Expected Value (EV): $1.86
# Potential Winnings: $5.97
# Combined Probability: 0.4780
# Combined Odds: 4.83
# Expected Value (EV): $1.31
# Potential Winnings: $4.83
# Combined Probability: 0.4747
# Combined Odds: 5.39
# Expected Value (EV): $1.56
# Potential Winnings: $5.39
# Combined Probability: 0.4556
# Combined Odds: 6.38
# Expected Value (EV): $1.91
# Potential Winnings: $6.38
# Combined Probability: 0.4556
# Combined Odds: 5.56
# Expected Value (EV): $1.53
# Potential Winnings: $5.56
# Combined Probability: 0.4513
# Combined Odds: 5.07
# Expected Value (EV): $1.29
# Potential Winnings: $5.07
# Combined Probability: 0.4454
# Combined Odds: 5.47
# Expected Value (EV): $1.44
# Potential Winnings: $5.47
# Combined Probability: 0.4444
# Combined Odds: 4.87
# Expected Value (EV): $1.16
# Potential Winnings: $4.87
# Combined Probability: 0.4444
# Combined Odds: 5.74
# Expected Value (EV): $1.55
# Potential Winnings: $5.74
# Combined Probability: 0.4405
# Combined Odds: 5.39
# Expected Value (EV): $1.38
# Potential Winnings: $5.39
# Combined Probability: 0.4343
# Combined Odds: 5.85
# Expected Value (EV): $1.54
# Potential Winnings: $5.85
# Combined Probability: 0.4343
# Combined Odds: 6.54
# Expected Value (EV): $1.84
# Potential Winnings: $6.54
# Combined Probability: 0.4167
# Combined Odds: 5.74
# Expected Value (EV): $1.39
# Potential Winnings: $5.74
# Combined Probability: 0.4157
# Combined Odds: 5.65
# Expected Value (EV): $1.35
# Potential Winnings: $5.65
# Combined Probability: 0.4147
# Combined Odds: 5.65
# Expected Value (EV): $1.34
# Potential Winnings: $5.65
# Combined Probability: 0.4111
# Combined Odds: 5.19
# Expected Value (EV): $1.13
# Potential Winnings: $5.19
# Combined Probability: 0.4102
# Combined Odds: 5.25
# Expected Value (EV): $1.15
# Potential Winnings: $5.25
# Combined Probability: 0.4009
# Combined Odds: 5.74
# Expected Value (EV): $1.30
# Potential Winnings: $5.74
# Combined Probability: 0.3977
# Combined Odds: 5.65
# Expected Value (EV): $1.25
# Potential Winnings: $5.65
# Combined Probability: 0.3962
# Combined Odds: 6.38
# Expected Value (EV): $1.53
# Potential Winnings: $6.38
# Combined Probability: 0.3956
# Combined Odds: 6.23
# Expected Value (EV): $1.47
# Potential Winnings: $6.23
# Combined Probability: 0.3941
# Combined Odds: 5.85
# Expected Value (EV): $1.31
# Potential Winnings: $5.85
# Combined Probability: 0.3941
# Combined Odds: 5.47
# Expected Value (EV): $1.16
# Potential Winnings: $5.47
# Combined Probability: 0.4758
# Combined Odds: 5.85
# Expected Value (EV): $1.78
# Potential Winnings: $5.85
# Combined Probability: 0.4731
# Combined Odds: 4.47
# Expected Value (EV): $1.11
# Potential Winnings: $4.47
# Combined Probability: 0.4642
# Combined Odds: 5.97
# Expected Value (EV): $1.77
# Potential Winnings: $5.97
# Combined Probability: 0.4636
# Combined Odds: 4.83
# Expected Value (EV): $1.24
# Potential Winnings: $4.83
# Combined Probability: 0.4604
# Combined Odds: 5.39
# Expected Value (EV): $1.48
# Potential Winnings: $5.39
# Combined Probability: 0.4419
# Combined Odds: 6.38
# Expected Value (EV): $1.82
# Potential Winnings: $6.38
# Combined Probability: 0.4419
# Combined Odds: 5.56
# Expected Value (EV): $1.46
# Potential Winnings: $5.56
# Combined Probability: 0.4377
# Combined Odds: 5.07
# Expected Value (EV): $1.22
# Potential Winnings: $5.07
# Combined Probability: 0.4320
# Combined Odds: 5.47
# Expected Value (EV): $1.36
# Potential Winnings: $5.47
# Combined Probability: 0.4310
# Combined Odds: 4.87
# Expected Value (EV): $1.10
# Potential Winnings: $4.87
# Combined Probability: 0.4310
# Combined Odds: 5.74
# Expected Value (EV): $1.48
# Potential Winnings: $5.74
# Combined Probability: 0.4273
# Combined Odds: 5.39
# Expected Value (EV): $1.30
# Potential Winnings: $5.39
# Combined Probability: 0.4215
# Combined Odds: 6.23
# Expected Value (EV): $1.63
# Potential Winnings: $6.23
# Combined Probability: 0.4212
# Combined Odds: 5.85
# Expected Value (EV): $1.46
# Potential Winnings: $5.85
# Combined Probability: 0.4212
# Combined Odds: 6.54
# Expected Value (EV): $1.76
# Potential Winnings: $6.54
# Combined Probability: 0.4042
# Combined Odds: 5.74
# Expected Value (EV): $1.32
# Potential Winnings: $5.74
# Combined Probability: 0.4032
# Combined Odds: 5.65
# Expected Value (EV): $1.28
# Potential Winnings: $5.65
# Combined Probability: 0.4022
# Combined Odds: 5.65
# Expected Value (EV): $1.27
# Potential Winnings: $5.65
# Combined Probability: 0.3987
# Combined Odds: 5.19
# Expected Value (EV): $1.07
# Potential Winnings: $5.19
# Combined Probability: 0.3857
# Combined Odds: 5.65
# Expected Value (EV): $1.18
# Potential Winnings: $5.65
# Combined Probability: 0.3843
# Combined Odds: 6.38
# Expected Value (EV): $1.45
# Potential Winnings: $6.38
# Combined Probability: 0.3837
# Combined Odds: 6.23
# Expected Value (EV): $1.39
# Potential Winnings: $6.23
# Combined Probability: 0.3823
# Combined Odds: 5.85
# Expected Value (EV): $1.24
# Potential Winnings: $5.85
# Combined Probability: 0.3823
# Combined Odds: 5.47
# Expected Value (EV): $1.09
# Potential Winnings: $5.47
# Combined Probability: 0.4692
# Combined Odds: 4.47
# Expected Value (EV): $1.10
# Potential Winnings: $4.47
# Combined Probability: 0.4604
# Combined Odds: 5.97
# Expected Value (EV): $1.75
# Potential Winnings: $5.97
# Combined Probability: 0.4566
# Combined Odds: 5.39
# Expected Value (EV): $1.46
# Potential Winnings: $5.39
# Combined Probability: 0.4383
# Combined Odds: 6.38
# Expected Value (EV): $1.80
# Potential Winnings: $6.38
# Combined Probability: 0.4383
# Combined Odds: 5.56
# Expected Value (EV): $1.43
# Potential Winnings: $5.56
# Combined Probability: 0.4341
# Combined Odds: 5.07
# Expected Value (EV): $1.20
# Potential Winnings: $5.07
# Combined Probability: 0.4275
# Combined Odds: 4.87
# Expected Value (EV): $1.08
# Potential Winnings: $4.87
# Combined Probability: 0.4275
# Combined Odds: 5.74
# Expected Value (EV): $1.46
# Potential Winnings: $5.74
# Combined Probability: 0.4238
# Combined Odds: 5.39
# Expected Value (EV): $1.29
# Potential Winnings: $5.39
# Combined Probability: 0.4181
# Combined Odds: 6.23
# Expected Value (EV): $1.60
# Potential Winnings: $6.23
# Combined Probability: 0.4178
# Combined Odds: 5.85
# Expected Value (EV): $1.44
# Potential Winnings: $5.85
# Combined Probability: 0.4177
# Combined Odds: 6.54
# Expected Value (EV): $1.73
# Potential Winnings: $6.54
# Combined Probability: 0.4008
# Combined Odds: 5.74
# Expected Value (EV): $1.30
# Potential Winnings: $5.74
# Combined Probability: 0.3999
# Combined Odds: 5.65
# Expected Value (EV): $1.26
# Potential Winnings: $5.65
# Combined Probability: 0.3989
# Combined Odds: 5.65
# Expected Value (EV): $1.25
# Potential Winnings: $5.65
# Combined Probability: 0.3954
# Combined Odds: 5.19
# Expected Value (EV): $1.05
# Potential Winnings: $5.19
# Combined Probability: 0.3946
# Combined Odds: 5.25
# Expected Value (EV): $1.07
# Potential Winnings: $5.25
# Combined Probability: 0.3856
# Combined Odds: 5.74
# Expected Value (EV): $1.22
# Potential Winnings: $5.74
# Combined Probability: 0.3826
# Combined Odds: 5.65
# Expected Value (EV): $1.16
# Potential Winnings: $5.65
# Combined Probability: 0.3806
# Combined Odds: 6.23
# Expected Value (EV): $1.37
# Potential Winnings: $6.23
# Combined Probability: 0.3791
# Combined Odds: 5.85
# Expected Value (EV): $1.22
# Potential Winnings: $5.85
# Combined Probability: 0.3791
# Combined Odds: 5.47
# Expected Value (EV): $1.07
# Potential Winnings: $5.47
# Combined Probability: 0.4578
# Combined Odds: 4.56
# Expected Value (EV): $1.09
# Potential Winnings: $4.56
# Combined Probability: 0.4573
# Combined Odds: 3.69
# Expected Value (EV): $0.69
# Potential Winnings: $3.69
# Combined Probability: 0.4541
# Combined Odds: 4.12
# Expected Value (EV): $0.87
# Potential Winnings: $4.12
# Combined Probability: 0.4358
# Combined Odds: 4.87
# Expected Value (EV): $1.12
# Potential Winnings: $4.87
# Combined Probability: 0.4358
# Combined Odds: 4.24
# Expected Value (EV): $0.85
# Potential Winnings: $4.24
# Combined Probability: 0.4317
# Combined Odds: 3.87
# Expected Value (EV): $0.67
# Potential Winnings: $3.87
# Combined Probability: 0.4261
# Combined Odds: 4.18
# Expected Value (EV): $0.78
# Potential Winnings: $4.18
# Combined Probability: 0.4251
# Combined Odds: 3.72
# Expected Value (EV): $0.58
# Potential Winnings: $3.72
# Combined Probability: 0.4251
# Combined Odds: 4.39
# Expected Value (EV): $0.86
# Potential Winnings: $4.39
# Combined Probability: 0.4214
# Combined Odds: 4.12
# Expected Value (EV): $0.74
# Potential Winnings: $4.12
# Combined Probability: 0.4155
# Combined Odds: 4.47
# Expected Value (EV): $0.86
# Potential Winnings: $4.47
# Combined Probability: 0.4154
# Combined Odds: 5.00
# Expected Value (EV): $1.08
# Potential Winnings: $5.00
# Combined Probability: 0.3986
# Combined Odds: 4.39
# Expected Value (EV): $0.75
# Potential Winnings: $4.39
# Combined Probability: 0.3977
# Combined Odds: 4.31
# Expected Value (EV): $0.71
# Potential Winnings: $4.31
# Combined Probability: 0.3967
# Combined Odds: 4.31
# Expected Value (EV): $0.71
# Potential Winnings: $4.31
# Combined Probability: 0.3932
# Combined Odds: 3.96
# Expected Value (EV): $0.56
# Potential Winnings: $3.96
# Combined Probability: 0.3924
# Combined Odds: 4.01
# Expected Value (EV): $0.57
# Potential Winnings: $4.01
# Combined Probability: 0.3835
# Combined Odds: 4.39
# Expected Value (EV): $0.68
# Potential Winnings: $4.39
# Combined Probability: 0.3804
# Combined Odds: 4.31
# Expected Value (EV): $0.64
# Potential Winnings: $4.31
# Combined Probability: 0.3790
# Combined Odds: 4.87
# Expected Value (EV): $0.85
# Potential Winnings: $4.87
# Combined Probability: 0.3784
# Combined Odds: 4.76
# Expected Value (EV): $0.80
# Potential Winnings: $4.76
# Combined Probability: 0.3770
# Combined Odds: 4.47
# Expected Value (EV): $0.68
# Potential Winnings: $4.47
# Combined Probability: 0.3770
# Combined Odds: 4.18
# Expected Value (EV): $0.58
# Potential Winnings: $4.18
# Combined Probability: 0.4487
# Combined Odds: 4.92
# Expected Value (EV): $1.21
# Potential Winnings: $4.92
# Combined Probability: 0.4455
# Combined Odds: 5.50
# Expected Value (EV): $1.45
# Potential Winnings: $5.50
# Combined Probability: 0.4277
# Combined Odds: 6.51
# Expected Value (EV): $1.78
# Potential Winnings: $6.51
# Combined Probability: 0.4277
# Combined Odds: 5.67
# Expected Value (EV): $1.42
# Potential Winnings: $5.67
# Combined Probability: 0.4236
# Combined Odds: 5.17
# Expected Value (EV): $1.19
# Potential Winnings: $5.17
# Combined Probability: 0.4181
# Combined Odds: 5.58
# Expected Value (EV): $1.33
# Potential Winnings: $5.58
# Combined Probability: 0.4171
# Combined Odds: 4.97
# Expected Value (EV): $1.07
# Potential Winnings: $4.97
# Combined Probability: 0.4171
# Combined Odds: 5.86
# Expected Value (EV): $1.44
# Potential Winnings: $5.86
# Combined Probability: 0.4135
# Combined Odds: 5.50
# Expected Value (EV): $1.27
# Potential Winnings: $5.50
# Combined Probability: 0.4079
# Combined Odds: 6.35
# Expected Value (EV): $1.59
# Potential Winnings: $6.35
# Combined Probability: 0.4077
# Combined Odds: 5.97
# Expected Value (EV): $1.43
# Potential Winnings: $5.97
# Combined Probability: 0.4076
# Combined Odds: 6.67
# Expected Value (EV): $1.72
# Potential Winnings: $6.67
# Combined Probability: 0.3911
# Combined Odds: 5.86
# Expected Value (EV): $1.29
# Potential Winnings: $5.86
# Combined Probability: 0.3902
# Combined Odds: 5.76
# Expected Value (EV): $1.25
# Potential Winnings: $5.76
# Combined Probability: 0.3859
# Combined Odds: 5.29
# Expected Value (EV): $1.04
# Potential Winnings: $5.29
# Combined Probability: 0.3850
# Combined Odds: 5.35
# Expected Value (EV): $1.06
# Potential Winnings: $5.35
# Combined Probability: 0.3763
# Combined Odds: 5.86
# Expected Value (EV): $1.20
# Potential Winnings: $5.86
# Combined Probability: 0.3733
# Combined Odds: 5.76
# Expected Value (EV): $1.15
# Potential Winnings: $5.76
# Combined Probability: 0.3719
# Combined Odds: 6.51
# Expected Value (EV): $1.42
# Potential Winnings: $6.51
# Combined Probability: 0.3713
# Combined Odds: 6.35
# Expected Value (EV): $1.36
# Potential Winnings: $6.35
# Combined Probability: 0.3699
# Combined Odds: 5.97
# Expected Value (EV): $1.21
# Potential Winnings: $5.97
# Combined Probability: 0.3699
# Combined Odds: 5.58
# Expected Value (EV): $1.06
# Potential Winnings: $5.58
# Combined Probability: 0.4450
# Combined Odds: 4.45
# Expected Value (EV): $0.98
# Potential Winnings: $4.45
# Combined Probability: 0.4271
# Combined Odds: 5.27
# Expected Value (EV): $1.25
# Potential Winnings: $5.27
# Combined Probability: 0.4271
# Combined Odds: 4.58
# Expected Value (EV): $0.96
# Potential Winnings: $4.58
# Combined Probability: 0.4231
# Combined Odds: 4.18
# Expected Value (EV): $0.77
# Potential Winnings: $4.18
# Combined Probability: 0.4166
# Combined Odds: 4.02
# Expected Value (EV): $0.67
# Potential Winnings: $4.02
# Combined Probability: 0.4166
# Combined Odds: 4.74
# Expected Value (EV): $0.97
# Potential Winnings: $4.74
# Combined Probability: 0.4130
# Combined Odds: 4.45
# Expected Value (EV): $0.84
# Potential Winnings: $4.45
# Combined Probability: 0.4074
# Combined Odds: 5.14
# Expected Value (EV): $1.09
# Potential Winnings: $5.14
# Combined Probability: 0.4071
# Combined Odds: 4.83
# Expected Value (EV): $0.97
# Potential Winnings: $4.83
# Combined Probability: 0.4071
# Combined Odds: 5.40
# Expected Value (EV): $1.20
# Potential Winnings: $5.40
# Combined Probability: 0.3906
# Combined Odds: 4.74
# Expected Value (EV): $0.85
# Potential Winnings: $4.74
# Combined Probability: 0.3897
# Combined Odds: 4.66
# Expected Value (EV): $0.82
# Potential Winnings: $4.66
# Combined Probability: 0.3887
# Combined Odds: 4.66
# Expected Value (EV): $0.81
# Potential Winnings: $4.66
# Combined Probability: 0.3854
# Combined Odds: 4.28
# Expected Value (EV): $0.65
# Potential Winnings: $4.28
# Combined Probability: 0.3846
# Combined Odds: 4.33
# Expected Value (EV): $0.67
# Potential Winnings: $4.33
# Combined Probability: 0.3758
# Combined Odds: 4.74
# Expected Value (EV): $0.78
# Potential Winnings: $4.74
# Combined Probability: 0.3728
# Combined Odds: 4.66
# Expected Value (EV): $0.74
# Potential Winnings: $4.66
# Combined Probability: 0.3709
# Combined Odds: 5.14
# Expected Value (EV): $0.91
# Potential Winnings: $5.14
# Combined Probability: 0.3695
# Combined Odds: 4.83
# Expected Value (EV): $0.78
# Potential Winnings: $4.83
# Combined Probability: 0.3695
# Combined Odds: 4.51
# Expected Value (EV): $0.67
# Potential Winnings: $4.51
# Combined Probability: 0.4241
# Combined Odds: 5.88
# Expected Value (EV): $1.50
# Potential Winnings: $5.88
# Combined Probability: 0.4241
# Combined Odds: 5.12
# Expected Value (EV): $1.17
# Potential Winnings: $5.12
# Combined Probability: 0.4201
# Combined Odds: 4.67
# Expected Value (EV): $0.96
# Potential Winnings: $4.67
# Combined Probability: 0.4147
# Combined Odds: 5.04
# Expected Value (EV): $1.09
# Potential Winnings: $5.04
# Combined Probability: 0.4137
# Combined Odds: 4.49
# Expected Value (EV): $0.86
# Potential Winnings: $4.49
# Combined Probability: 0.4137
# Combined Odds: 5.29
# Expected Value (EV): $1.19
# Potential Winnings: $5.29
# Combined Probability: 0.4101
# Combined Odds: 4.97
# Expected Value (EV): $1.04
# Potential Winnings: $4.97
# Combined Probability: 0.4046
# Combined Odds: 5.74
# Expected Value (EV): $1.32
# Potential Winnings: $5.74
# Combined Probability: 0.4043
# Combined Odds: 5.39
# Expected Value (EV): $1.18
# Potential Winnings: $5.39
# Combined Probability: 0.3879
# Combined Odds: 5.29
# Expected Value (EV): $1.05
# Potential Winnings: $5.29
# Combined Probability: 0.3870
# Combined Odds: 5.20
# Expected Value (EV): $1.01
# Potential Winnings: $5.20
# Combined Probability: 0.3860
# Combined Odds: 5.20
# Expected Value (EV): $1.01
# Potential Winnings: $5.20
# Combined Probability: 0.3827
# Combined Odds: 4.78
# Expected Value (EV): $0.83
# Potential Winnings: $4.78
# Combined Probability: 0.3819
# Combined Odds: 4.84
# Expected Value (EV): $0.85
# Potential Winnings: $4.84
# Combined Probability: 0.3732
# Combined Odds: 5.29
# Expected Value (EV): $0.98
# Potential Winnings: $5.29
# Combined Probability: 0.3702
# Combined Odds: 5.20
# Expected Value (EV): $0.93
# Potential Winnings: $5.20
# Combined Probability: 0.3688
# Combined Odds: 5.88
# Expected Value (EV): $1.17
# Potential Winnings: $5.88
# Combined Probability: 0.3683
# Combined Odds: 5.74
# Expected Value (EV): $1.11
# Potential Winnings: $5.74
# Combined Probability: 0.3669
# Combined Odds: 5.39
# Expected Value (EV): $0.98
# Potential Winnings: $5.39
# Combined Probability: 0.3669
# Combined Odds: 5.04
# Expected Value (EV): $0.85
# Potential Winnings: $5.04
# Combined Probability: 0.4033
# Combined Odds: 5.53
# Expected Value (EV): $1.23
# Potential Winnings: $5.53
# Combined Probability: 0.3980
# Combined Odds: 5.97
# Expected Value (EV): $1.38
# Potential Winnings: $5.97
# Combined Probability: 0.3971
# Combined Odds: 5.31
# Expected Value (EV): $1.11
# Potential Winnings: $5.31
# Combined Probability: 0.3971
# Combined Odds: 6.27
# Expected Value (EV): $1.49
# Potential Winnings: $6.27
# Combined Probability: 0.3936
# Combined Odds: 5.88
# Expected Value (EV): $1.32
# Potential Winnings: $5.88
# Combined Probability: 0.3883
# Combined Odds: 6.80
# Expected Value (EV): $1.64
# Potential Winnings: $6.80
# Combined Probability: 0.3881
# Combined Odds: 6.38
# Expected Value (EV): $1.48
# Potential Winnings: $6.38
# Combined Probability: 0.3880
# Combined Odds: 7.14
# Expected Value (EV): $1.77
# Potential Winnings: $7.14
# Combined Probability: 0.3723
# Combined Odds: 6.27
# Expected Value (EV): $1.33
# Potential Winnings: $6.27
# Combined Probability: 0.3715
# Combined Odds: 6.16
# Expected Value (EV): $1.29
# Potential Winnings: $6.16
# Combined Probability: 0.3705
# Combined Odds: 6.16
# Expected Value (EV): $1.28
# Potential Winnings: $6.16
# Combined Probability: 0.3673
# Combined Odds: 5.66
# Expected Value (EV): $1.08
# Potential Winnings: $5.66
# Combined Probability: 0.3665
# Combined Odds: 5.73
# Expected Value (EV): $1.10
# Potential Winnings: $5.73
# Combined Probability: 0.3582
# Combined Odds: 6.27
# Expected Value (EV): $1.24
# Potential Winnings: $6.27
# Combined Probability: 0.3553
# Combined Odds: 6.16
# Expected Value (EV): $1.19
# Potential Winnings: $6.16
# Combined Probability: 0.3540
# Combined Odds: 6.96
# Expected Value (EV): $1.46
# Potential Winnings: $6.96
# Combined Probability: 0.3535
# Combined Odds: 6.80
# Expected Value (EV): $1.40
# Potential Winnings: $6.80
# Combined Probability: 0.3522
# Combined Odds: 6.38
# Expected Value (EV): $1.25
# Potential Winnings: $6.38
# Combined Probability: 0.3522
# Combined Odds: 5.97
# Expected Value (EV): $1.10
# Potential Winnings: $5.97
# Combined Probability: 0.4033
# Combined Odds: 4.81
# Expected Value (EV): $0.94
# Potential Winnings: $4.81
# Combined Probability: 0.3980
# Combined Odds: 5.19
# Expected Value (EV): $1.07
# Potential Winnings: $5.19
# Combined Probability: 0.3971
# Combined Odds: 4.63
# Expected Value (EV): $0.84
# Potential Winnings: $4.63
# Combined Probability: 0.3971
# Combined Odds: 5.45
# Expected Value (EV): $1.17
# Potential Winnings: $5.45
# Combined Probability: 0.3936
# Combined Odds: 5.12
# Expected Value (EV): $1.02
# Potential Winnings: $5.12
# Combined Probability: 0.3883
# Combined Odds: 5.92
# Expected Value (EV): $1.30
# Potential Winnings: $5.92
# Combined Probability: 0.3881
# Combined Odds: 5.56
# Expected Value (EV): $1.16
# Potential Winnings: $5.56
# Combined Probability: 0.3880
# Combined Odds: 6.21
# Expected Value (EV): $1.41
# Potential Winnings: $6.21
# Combined Probability: 0.3723
# Combined Odds: 5.45
# Expected Value (EV): $1.03
# Potential Winnings: $5.45
# Combined Probability: 0.3715
# Combined Odds: 5.36
# Expected Value (EV): $0.99
# Potential Winnings: $5.36
# Combined Probability: 0.3705
# Combined Odds: 5.36
# Expected Value (EV): $0.99
# Potential Winnings: $5.36
# Combined Probability: 0.3673
# Combined Odds: 4.92
# Expected Value (EV): $0.81
# Potential Winnings: $4.92
# Combined Probability: 0.3665
# Combined Odds: 4.99
# Expected Value (EV): $0.83
# Potential Winnings: $4.99
# Combined Probability: 0.3582
# Combined Odds: 5.45
# Expected Value (EV): $0.95
# Potential Winnings: $5.45
# Combined Probability: 0.3553
# Combined Odds: 5.36
# Expected Value (EV): $0.91
# Potential Winnings: $5.36
# Combined Probability: 0.3540
# Combined Odds: 6.06
# Expected Value (EV): $1.15
# Potential Winnings: $6.06
# Combined Probability: 0.3535
# Combined Odds: 5.92
# Expected Value (EV): $1.09
# Potential Winnings: $5.92
# Combined Probability: 0.3522
# Combined Odds: 5.56
# Expected Value (EV): $0.96
# Potential Winnings: $5.56
# Combined Probability: 0.3522
# Combined Odds: 5.19
# Expected Value (EV): $0.83
# Potential Winnings: $5.19
# Combined Probability: 0.3942
# Combined Odds: 4.74
# Expected Value (EV): $0.87
# Potential Winnings: $4.74
# Combined Probability: 0.3933
# Combined Odds: 4.22
# Expected Value (EV): $0.66
# Potential Winnings: $4.22
# Combined Probability: 0.3933
# Combined Odds: 4.98
# Expected Value (EV): $0.96
# Potential Winnings: $4.98
# Combined Probability: 0.3899
# Combined Odds: 4.67
# Expected Value (EV): $0.82
# Potential Winnings: $4.67
# Combined Probability: 0.3847
# Combined Odds: 5.40
# Expected Value (EV): $1.08
# Potential Winnings: $5.40
# Combined Probability: 0.3844
# Combined Odds: 5.07
# Expected Value (EV): $0.95
# Potential Winnings: $5.07
# Combined Probability: 0.3843
# Combined Odds: 5.67
# Expected Value (EV): $1.18
# Potential Winnings: $5.67
# Combined Probability: 0.3688
# Combined Odds: 4.98
# Expected Value (EV): $0.84
# Potential Winnings: $4.98
# Combined Probability: 0.3680
# Combined Odds: 4.89
# Expected Value (EV): $0.80
# Potential Winnings: $4.89
# Combined Probability: 0.3670
# Combined Odds: 4.89
# Expected Value (EV): $0.80
# Potential Winnings: $4.89
# Combined Probability: 0.3638
# Combined Odds: 4.49
# Expected Value (EV): $0.63
# Potential Winnings: $4.49
# Combined Probability: 0.3631
# Combined Odds: 4.55
# Expected Value (EV): $0.65
# Potential Winnings: $4.55
# Combined Probability: 0.3548
# Combined Odds: 4.98
# Expected Value (EV): $0.77
# Potential Winnings: $4.98
# Combined Probability: 0.3520
# Combined Odds: 4.89
# Expected Value (EV): $0.72
# Potential Winnings: $4.89
# Combined Probability: 0.3507
# Combined Odds: 5.53
# Expected Value (EV): $0.94
# Potential Winnings: $5.53
# Combined Probability: 0.3502
# Combined Odds: 5.40
# Expected Value (EV): $0.89
# Potential Winnings: $5.40
# Combined Probability: 0.3488
# Combined Odds: 5.07
# Expected Value (EV): $0.77
# Potential Winnings: $5.07
# Combined Probability: 0.3488
# Combined Odds: 4.74
# Expected Value (EV): $0.65
# Potential Winnings: $4.74
# Combined Probability: 0.3882
# Combined Odds: 4.55
# Expected Value (EV): $0.77
# Potential Winnings: $4.55
# Combined Probability: 0.3882
# Combined Odds: 5.37
# Expected Value (EV): $1.09
# Potential Winnings: $5.37
# Combined Probability: 0.3848
# Combined Odds: 5.04
# Expected Value (EV): $0.94
# Potential Winnings: $5.04
# Combined Probability: 0.3797
# Combined Odds: 5.83
# Expected Value (EV): $1.21
# Potential Winnings: $5.83
# Combined Probability: 0.3794
# Combined Odds: 5.47
# Expected Value (EV): $1.08
# Potential Winnings: $5.47
# Combined Probability: 0.3793
# Combined Odds: 6.12
# Expected Value (EV): $1.32
# Potential Winnings: $6.12
# Combined Probability: 0.3640
# Combined Odds: 5.37
# Expected Value (EV): $0.96
# Potential Winnings: $5.37
# Combined Probability: 0.3632
# Combined Odds: 5.28
# Expected Value (EV): $0.92
# Potential Winnings: $5.28
# Combined Probability: 0.3622
# Combined Odds: 5.28
# Expected Value (EV): $0.91
# Potential Winnings: $5.28
# Combined Probability: 0.3591
# Combined Odds: 4.85
# Expected Value (EV): $0.74
# Potential Winnings: $4.85
# Combined Probability: 0.3584
# Combined Odds: 4.91
# Expected Value (EV): $0.76
# Potential Winnings: $4.91
# Combined Probability: 0.3502
# Combined Odds: 5.37
# Expected Value (EV): $0.88
# Potential Winnings: $5.37
# Combined Probability: 0.3474
# Combined Odds: 5.28
# Expected Value (EV): $0.83
# Potential Winnings: $5.28
# Combined Probability: 0.3456
# Combined Odds: 5.83
# Expected Value (EV): $1.01
# Potential Winnings: $5.83
# Combined Probability: 0.3443
# Combined Odds: 5.47
# Expected Value (EV): $0.88
# Potential Winnings: $5.47
# Combined Probability: 0.3443
# Combined Odds: 5.12
# Expected Value (EV): $0.76
# Potential Winnings: $5.12
# Combined Probability: 0.3873
# Combined Odds: 4.78
# Expected Value (EV): $0.85
# Potential Winnings: $4.78
# Combined Probability: 0.3839
# Combined Odds: 4.49
# Expected Value (EV): $0.72
# Potential Winnings: $4.49
# Combined Probability: 0.3788
# Combined Odds: 5.19
# Expected Value (EV): $0.96
# Potential Winnings: $5.19
# Combined Probability: 0.3785
# Combined Odds: 4.87
# Expected Value (EV): $0.84
# Potential Winnings: $4.87
# Combined Probability: 0.3784
# Combined Odds: 5.45
# Expected Value (EV): $1.06
# Potential Winnings: $5.45
# Combined Probability: 0.3631
# Combined Odds: 4.78
# Expected Value (EV): $0.74
# Potential Winnings: $4.78
# Combined Probability: 0.3623
# Combined Odds: 4.70
# Expected Value (EV): $0.70
# Potential Winnings: $4.70
# Combined Probability: 0.3614
# Combined Odds: 4.70
# Expected Value (EV): $0.70
# Potential Winnings: $4.70
# Combined Probability: 0.3575
# Combined Odds: 4.37
# Expected Value (EV): $0.56
# Potential Winnings: $4.37
# Combined Probability: 0.3494
# Combined Odds: 4.78
# Expected Value (EV): $0.67
# Potential Winnings: $4.78
# Combined Probability: 0.3466
# Combined Odds: 4.70
# Expected Value (EV): $0.63
# Potential Winnings: $4.70
# Combined Probability: 0.3453
# Combined Odds: 5.31
# Expected Value (EV): $0.83
# Potential Winnings: $5.31
# Combined Probability: 0.3435
# Combined Odds: 4.87
# Expected Value (EV): $0.67
# Potential Winnings: $4.87
# Combined Probability: 0.3435
# Combined Odds: 4.55
# Expected Value (EV): $0.56
# Potential Winnings: $4.55
# Combined Probability: 0.3788
# Combined Odds: 6.12
# Expected Value (EV): $1.32
# Potential Winnings: $6.12
# Combined Probability: 0.3785
# Combined Odds: 5.74
# Expected Value (EV): $1.17
# Potential Winnings: $5.74
# Combined Probability: 0.3784
# Combined Odds: 6.42
# Expected Value (EV): $1.43
# Potential Winnings: $6.42
# Combined Probability: 0.3623
# Combined Odds: 5.54
# Expected Value (EV): $1.01
# Potential Winnings: $5.54
# Combined Probability: 0.3614
# Combined Odds: 5.54
# Expected Value (EV): $1.00
# Potential Winnings: $5.54
# Combined Probability: 0.3583
# Combined Odds: 5.09
# Expected Value (EV): $0.82
# Potential Winnings: $5.09
# Combined Probability: 0.3575
# Combined Odds: 5.15
# Expected Value (EV): $0.84
# Potential Winnings: $5.15
# Combined Probability: 0.3494
# Combined Odds: 5.64
# Expected Value (EV): $0.97
# Potential Winnings: $5.64
# Combined Probability: 0.3466
# Combined Odds: 5.54
# Expected Value (EV): $0.92
# Potential Winnings: $5.54
# Combined Probability: 0.3453
# Combined Odds: 6.27
# Expected Value (EV): $1.16
# Potential Winnings: $6.27
# Combined Probability: 0.3448
# Combined Odds: 6.12
# Expected Value (EV): $1.11
# Potential Winnings: $6.12
# Combined Probability: 0.3435
# Combined Odds: 5.74
# Expected Value (EV): $0.97
# Potential Winnings: $5.74
# Combined Probability: 0.3435
# Combined Odds: 5.37
# Expected Value (EV): $0.84
# Potential Winnings: $5.37
# Combined Probability: 0.3755
# Combined Odds: 5.74
# Expected Value (EV): $1.16
# Potential Winnings: $5.74
# Combined Probability: 0.3752
# Combined Odds: 5.39
# Expected Value (EV): $1.02
# Potential Winnings: $5.39
# Combined Probability: 0.3752
# Combined Odds: 6.03
# Expected Value (EV): $1.26
# Potential Winnings: $6.03
# Combined Probability: 0.3592
# Combined Odds: 5.20
# Expected Value (EV): $0.87
# Potential Winnings: $5.20
# Combined Probability: 0.3582
# Combined Odds: 5.20
# Expected Value (EV): $0.86
# Potential Winnings: $5.20
# Combined Probability: 0.3552
# Combined Odds: 4.78
# Expected Value (EV): $0.70
# Potential Winnings: $4.78
# Combined Probability: 0.3544
# Combined Odds: 4.84
# Expected Value (EV): $0.71
# Potential Winnings: $4.84
# Combined Probability: 0.3463
# Combined Odds: 5.29
# Expected Value (EV): $0.83
# Potential Winnings: $5.29
# Combined Probability: 0.3436
# Combined Odds: 5.20
# Expected Value (EV): $0.79
# Potential Winnings: $5.20
# Combined Probability: 0.3423
# Combined Odds: 5.88
# Expected Value (EV): $1.01
# Potential Winnings: $5.88
# Combined Probability: 0.3418
# Combined Odds: 5.74
# Expected Value (EV): $0.96
# Potential Winnings: $5.74
# Combined Probability: 0.3405
# Combined Odds: 5.39
# Expected Value (EV): $0.84
# Potential Winnings: $5.39
# Combined Probability: 0.3405
# Combined Odds: 5.04
# Expected Value (EV): $0.72
# Potential Winnings: $5.04
# Combined Probability: 0.3702
# Combined Odds: 6.23
# Expected Value (EV): $1.31
# Potential Winnings: $6.23
# Combined Probability: 0.3701
# Combined Odds: 6.97
# Expected Value (EV): $1.58
# Potential Winnings: $6.97
# Combined Probability: 0.3552
# Combined Odds: 6.12
# Expected Value (EV): $1.17
# Potential Winnings: $6.12
# Combined Probability: 0.3543
# Combined Odds: 6.01
# Expected Value (EV): $1.13
# Potential Winnings: $6.01
# Combined Probability: 0.3534
# Combined Odds: 6.01
# Expected Value (EV): $1.13
# Potential Winnings: $6.01
# Combined Probability: 0.3504
# Combined Odds: 5.52
# Expected Value (EV): $0.94
# Potential Winnings: $5.52
# Combined Probability: 0.3496
# Combined Odds: 5.59
# Expected Value (EV): $0.95
# Potential Winnings: $5.59
# Combined Probability: 0.3417
# Combined Odds: 6.12
# Expected Value (EV): $1.09
# Potential Winnings: $6.12
# Combined Probability: 0.3390
# Combined Odds: 6.01
# Expected Value (EV): $1.04
# Potential Winnings: $6.01
# Combined Probability: 0.3377
# Combined Odds: 6.80
# Expected Value (EV): $1.30
# Potential Winnings: $6.80
# Combined Probability: 0.3372
# Combined Odds: 6.64
# Expected Value (EV): $1.24
# Potential Winnings: $6.64
# Combined Probability: 0.3359
# Combined Odds: 6.23
# Expected Value (EV): $1.09
# Potential Winnings: $6.23
# Combined Probability: 0.3359
# Combined Odds: 5.83
# Expected Value (EV): $0.96
# Potential Winnings: $5.83
# Combined Probability: 0.3699
# Combined Odds: 6.54
# Expected Value (EV): $1.42
# Potential Winnings: $6.54
# Combined Probability: 0.3549
# Combined Odds: 5.74
# Expected Value (EV): $1.04
# Potential Winnings: $5.74
# Combined Probability: 0.3541
# Combined Odds: 5.65
# Expected Value (EV): $1.00
# Potential Winnings: $5.65
# Combined Probability: 0.3532
# Combined Odds: 5.65
# Expected Value (EV): $0.99
# Potential Winnings: $5.65
# Combined Probability: 0.3501
# Combined Odds: 5.19
# Expected Value (EV): $0.82
# Potential Winnings: $5.19
# Combined Probability: 0.3494
# Combined Odds: 5.25
# Expected Value (EV): $0.83
# Potential Winnings: $5.25
# Combined Probability: 0.3415
# Combined Odds: 5.74
# Expected Value (EV): $0.96
# Potential Winnings: $5.74
# Combined Probability: 0.3387
# Combined Odds: 5.65
# Expected Value (EV): $0.91
# Potential Winnings: $5.65
# Combined Probability: 0.3374
# Combined Odds: 6.38
# Expected Value (EV): $1.15
# Potential Winnings: $6.38
# Combined Probability: 0.3370
# Combined Odds: 6.23
# Expected Value (EV): $1.10
# Potential Winnings: $6.23
# Combined Probability: 0.3357
# Combined Odds: 5.47
# Expected Value (EV): $0.84
# Potential Winnings: $5.47
# Combined Probability: 0.3549
# Combined Odds: 6.42
# Expected Value (EV): $1.28
# Potential Winnings: $6.42
# Combined Probability: 0.3541
# Combined Odds: 6.31
# Expected Value (EV): $1.24
# Potential Winnings: $6.31
# Combined Probability: 0.3531
# Combined Odds: 6.31
# Expected Value (EV): $1.23
# Potential Winnings: $6.31
# Combined Probability: 0.3501
# Combined Odds: 5.80
# Expected Value (EV): $1.03
# Potential Winnings: $5.80
# Combined Probability: 0.3493
# Combined Odds: 5.87
# Expected Value (EV): $1.05
# Potential Winnings: $5.87
# Combined Probability: 0.3414
# Combined Odds: 6.42
# Expected Value (EV): $1.19
# Potential Winnings: $6.42
# Combined Probability: 0.3387
# Combined Odds: 6.31
# Expected Value (EV): $1.14
# Potential Winnings: $6.31
# Combined Probability: 0.3374
# Combined Odds: 7.14
# Expected Value (EV): $1.41
# Potential Winnings: $7.14
# Combined Probability: 0.3369
# Combined Odds: 6.97
# Expected Value (EV): $1.35
# Potential Winnings: $6.97
# Combined Probability: 0.3357
# Combined Odds: 6.54
# Expected Value (EV): $1.20
# Potential Winnings: $6.54
# Combined Probability: 0.3357
# Combined Odds: 6.12
# ...
# Combined Odds: 6.69
# Expected Value (EV): $0.57
# Potential Winnings: $6.69
# Combined Probability: 0.2343
# Combined Odds: 7.57
# Expected Value (EV): $0.77
# Potential Winnings: $7.57
# Combined Probability: 0.2339
# Combined Odds: 7.39
# Expected Value (EV): $0.73
# Potential Winnings: $7.39
# Combined Probability: 0.2331
# Combined Odds: 6.94
# Expected Value (EV): $0.62
# Potential Winnings: $6.94
# Combined Probability: 0.2331
# Combined Odds: 6.49
# Expected Value (EV): $0.51
# Potential Winnings: $6.49
# Combined Probability: 0.2298
# Combined Odds: 7.32
# Expected Value (EV): $0.68
# Potential Winnings: $7.32
# Combined Probability: 0.2289
# Combined Odds: 8.28
# Expected Value (EV): $0.90
# Potential Winnings: $8.28
# Combined Probability: 0.2286
# Combined Odds: 8.08
# Expected Value (EV): $0.85
# Potential Winnings: $8.08
# Combined Probability: 0.2278
# Combined Odds: 7.59
# Expected Value (EV): $0.73
# Potential Winnings: $7.59
# Combined Probability: 0.2278
# Combined Odds: 7.10
# Expected Value (EV): $0.62
# Potential Winnings: $7.10
# Combined Probability: 0.2271
# Combined Odds: 8.14
# Expected Value (EV): $0.85
# Potential Winnings: $8.14
# Combined Probability: 0.2268
# Combined Odds: 7.94
# Expected Value (EV): $0.80
# Potential Winnings: $7.94
# Combined Probability: 0.2259
# Combined Odds: 7.46
# Expected Value (EV): $0.69
# Potential Winnings: $7.46
# Combined Probability: 0.2259
# Combined Odds: 8.98
# Expected Value (EV): $1.03
# Potential Winnings: $8.98
# Combined Probability: 0.2251
# Combined Odds: 8.43
# Expected Value (EV): $0.90
# Potential Winnings: $8.43
# Combined Probability: 0.2251
# Combined Odds: 7.89
# Expected Value (EV): $0.77
# Potential Winnings: $7.89
# Combined Probability: 0.2248
# Combined Odds: 8.23
# Expected Value (EV): $0.85
# Potential Winnings: $8.23
# Combined Probability: 0.2248
# Combined Odds: 7.70
# Expected Value (EV): $0.73
# Potential Winnings: $7.70
# Combined Probability: 0.2239
# Combined Odds: 7.23
# Expected Value (EV): $0.62
# Potential Winnings: $7.23
# Combined Probability: 0.2466
# Combined Odds: 5.63
# Expected Value (EV): $0.39
# Potential Winnings: $5.63
# Combined Probability: 0.2444
# Combined Odds: 5.17
# Expected Value (EV): $0.26
# Potential Winnings: $5.17
# Combined Probability: 0.2439
# Combined Odds: 5.24
# Expected Value (EV): $0.28
# Potential Winnings: $5.24
# Combined Probability: 0.2384
# Combined Odds: 5.73
# Expected Value (EV): $0.37
# Potential Winnings: $5.73
# Combined Probability: 0.2365
# Combined Odds: 5.63
# Expected Value (EV): $0.33
# Potential Winnings: $5.63
# Combined Probability: 0.2356
# Combined Odds: 6.37
# Expected Value (EV): $0.50
# Potential Winnings: $6.37
# Combined Probability: 0.2352
# Combined Odds: 6.22
# Expected Value (EV): $0.46
# Potential Winnings: $6.22
# Combined Probability: 0.2343
# Combined Odds: 5.84
# Expected Value (EV): $0.37
# Potential Winnings: $5.84
# Combined Probability: 0.2343
# Combined Odds: 5.46
# Expected Value (EV): $0.28
# Potential Winnings: $5.46
# Combined Probability: 0.2438
# Combined Odds: 5.17
# Expected Value (EV): $0.26
# Potential Winnings: $5.17
# Combined Probability: 0.2433
# Combined Odds: 5.24
# Expected Value (EV): $0.27
# Potential Winnings: $5.24
# Combined Probability: 0.2377
# Combined Odds: 5.73
# Expected Value (EV): $0.36
# Potential Winnings: $5.73
# Combined Probability: 0.2358
# Combined Odds: 5.63
# Expected Value (EV): $0.33
# Potential Winnings: $5.63
# Combined Probability: 0.2350
# Combined Odds: 6.37
# Expected Value (EV): $0.50
# Potential Winnings: $6.37
# Combined Probability: 0.2346
# Combined Odds: 6.22
# Expected Value (EV): $0.46
# Potential Winnings: $6.22
# Combined Probability: 0.2337
# Combined Odds: 5.84
# Expected Value (EV): $0.36
# Potential Winnings: $5.84
# Combined Probability: 0.2337
# Combined Odds: 5.46
# Expected Value (EV): $0.28
# Potential Winnings: $5.46
# Combined Probability: 0.2412
# Combined Odds: 4.81
# Expected Value (EV): $0.16
# Potential Winnings: $4.81
# Combined Probability: 0.2357
# Combined Odds: 5.27
# Expected Value (EV): $0.24
# Potential Winnings: $5.27
# Combined Probability: 0.2338
# Combined Odds: 5.18
# Expected Value (EV): $0.21
# Potential Winnings: $5.18
# Combined Probability: 0.2329
# Combined Odds: 5.85
# Expected Value (EV): $0.36
# Potential Winnings: $5.85
# Combined Probability: 0.2317
# Combined Odds: 5.36
# Expected Value (EV): $0.24
# Potential Winnings: $5.36
# Combined Probability: 0.2317
# Combined Odds: 5.01
# Expected Value (EV): $0.16
# Potential Winnings: $5.01
# Combined Probability: 0.2333
# Combined Odds: 5.24
# Expected Value (EV): $0.22
# Potential Winnings: $5.24
# Combined Probability: 0.2324
# Combined Odds: 5.92
# Expected Value (EV): $0.38
# Potential Winnings: $5.92
# Combined Probability: 0.2321
# Combined Odds: 5.78
# Expected Value (EV): $0.34
# Potential Winnings: $5.78
# Combined Probability: 0.2312
# Combined Odds: 5.43
# Expected Value (EV): $0.26
# Potential Winnings: $5.43
# Combined Probability: 0.2312
# Combined Odds: 5.08
# Expected Value (EV): $0.17
# Potential Winnings: $5.08
# Combined Probability: 0.2280
# Combined Odds: 5.73
# Expected Value (EV): $0.31
# Potential Winnings: $5.73
# Combined Probability: 0.2271
# Combined Odds: 6.48
# Expected Value (EV): $0.47
# Potential Winnings: $6.48
# Combined Probability: 0.2268
# Combined Odds: 6.33
# Expected Value (EV): $0.43
# Potential Winnings: $6.33
# Combined Probability: 0.2260
# Combined Odds: 5.94
# Expected Value (EV): $0.34
# Potential Winnings: $5.94
# Combined Probability: 0.2260
# Combined Odds: 5.55
# Expected Value (EV): $0.26
# Potential Winnings: $5.55
# Combined Probability: 0.2253
# Combined Odds: 6.37
# Expected Value (EV): $0.44
# Potential Winnings: $6.37
# Combined Probability: 0.2250
# Combined Odds: 6.22
# Expected Value (EV): $0.40
# Potential Winnings: $6.22
# Combined Probability: 0.2242
# Combined Odds: 5.84
# Expected Value (EV): $0.31
# Potential Winnings: $5.84
# Combined Probability: 0.2242
# Combined Odds: 7.03
# Expected Value (EV): $0.58
# Potential Winnings: $7.03
# Combined Probability: 0.2233
# Combined Odds: 6.60
# Expected Value (EV): $0.47
# Potential Winnings: $6.60
# Combined Probability: 0.2233
# Combined Odds: 6.17
# Expected Value (EV): $0.38
# Potential Winnings: $6.17
# Combined Probability: 0.2230
# Combined Odds: 6.44
# Expected Value (EV): $0.44
# Potential Winnings: $6.44
# Combined Probability: 0.2230
# Combined Odds: 6.02
# Expected Value (EV): $0.34
# Potential Winnings: $6.02
# Combined Probability: 0.2222
# Combined Odds: 5.66
# Expected Value (EV): $0.26
# Potential Winnings: $5.66
# Combined Probability: 0.2432
# Combined Odds: 5.09
# Expected Value (EV): $0.24
# Potential Winnings: $5.09
# Combined Probability: 0.2427
# Combined Odds: 5.15
# Expected Value (EV): $0.25
# Potential Winnings: $5.15
# Combined Probability: 0.2372
# Combined Odds: 5.63
# Expected Value (EV): $0.34
# Potential Winnings: $5.63
# Combined Probability: 0.2353
# Combined Odds: 5.54
# Expected Value (EV): $0.30
# Potential Winnings: $5.54
# Combined Probability: 0.2344
# Combined Odds: 6.26
# Expected Value (EV): $0.47
# Potential Winnings: $6.26
# Combined Probability: 0.2341
# Combined Odds: 6.11
# Expected Value (EV): $0.43
# Potential Winnings: $6.11
# Combined Probability: 0.2332
# Combined Odds: 5.74
# Expected Value (EV): $0.34
# Potential Winnings: $5.74
# Combined Probability: 0.2332
# Combined Odds: 5.37
# Expected Value (EV): $0.25
# Potential Winnings: $5.37
# Combined Probability: 0.2406
# Combined Odds: 4.73
# Expected Value (EV): $0.14
# Potential Winnings: $4.73
# Combined Probability: 0.2352
# Combined Odds: 5.17
# Expected Value (EV): $0.22
# Potential Winnings: $5.17
# Combined Probability: 0.2333
# Combined Odds: 5.09
# Expected Value (EV): $0.19
# Potential Winnings: $5.09
# Combined Probability: 0.2324
# Combined Odds: 5.75
# Expected Value (EV): $0.34
# Potential Winnings: $5.75
# Combined Probability: 0.2312
# Combined Odds: 5.27
# Expected Value (EV): $0.22
# Potential Winnings: $5.27
# Combined Probability: 0.2312
# Combined Odds: 4.93
# Expected Value (EV): $0.14
# Potential Winnings: $4.93
# Combined Probability: 0.2328
# Combined Odds: 5.15
# Expected Value (EV): $0.20
# Potential Winnings: $5.15
# Combined Probability: 0.2319
# Combined Odds: 5.82
# Expected Value (EV): $0.35
# Potential Winnings: $5.82
# Combined Probability: 0.2316
# Combined Odds: 5.68
# Expected Value (EV): $0.32
# Potential Winnings: $5.68
# Combined Probability: 0.2307
# Combined Odds: 5.34
# Expected Value (EV): $0.23
# Potential Winnings: $5.34
# Combined Probability: 0.2307
# Combined Odds: 4.99
# Expected Value (EV): $0.15
# Potential Winnings: $4.99
# Combined Probability: 0.2275
# Combined Odds: 5.63
# Expected Value (EV): $0.28
# Potential Winnings: $5.63
# Combined Probability: 0.2266
# Combined Odds: 6.37
# Expected Value (EV): $0.44
# Potential Winnings: $6.37
# Combined Probability: 0.2263
# Combined Odds: 6.22
# Expected Value (EV): $0.41
# Potential Winnings: $6.22
# Combined Probability: 0.2255
# Combined Odds: 5.84
# Expected Value (EV): $0.32
# Potential Winnings: $5.84
# Combined Probability: 0.2255
# Combined Odds: 5.46
# Expected Value (EV): $0.23
# Potential Winnings: $5.46
# Combined Probability: 0.2248
# Combined Odds: 6.26
# Expected Value (EV): $0.41
# Potential Winnings: $6.26
# Combined Probability: 0.2245
# Combined Odds: 6.11
# Expected Value (EV): $0.37
# Potential Winnings: $6.11
# Combined Probability: 0.2237
# Combined Odds: 5.74
# Expected Value (EV): $0.28
# Potential Winnings: $5.74
# Combined Probability: 0.2237
# Combined Odds: 6.91
# Expected Value (EV): $0.55
# Potential Winnings: $6.91
# Combined Probability: 0.2228
# Combined Odds: 6.49
# Expected Value (EV): $0.45
# Potential Winnings: $6.49
# Combined Probability: 0.2228
# Combined Odds: 6.07
# Expected Value (EV): $0.35
# Potential Winnings: $6.07
# Combined Probability: 0.2225
# Combined Odds: 6.33
# Expected Value (EV): $0.41
# Potential Winnings: $6.33
# Combined Probability: 0.2225
# Combined Odds: 5.92
# Expected Value (EV): $0.32
# Potential Winnings: $5.92
# Combined Probability: 0.2217
# Combined Odds: 5.56
# Expected Value (EV): $0.23
# Potential Winnings: $5.56
# Combined Probability: 0.2400
# Combined Odds: 4.73
# Expected Value (EV): $0.14
# Potential Winnings: $4.73
# Combined Probability: 0.2346
# Combined Odds: 5.17
# Expected Value (EV): $0.21
# Potential Winnings: $5.17
# Combined Probability: 0.2327
# Combined Odds: 5.09
# Expected Value (EV): $0.18
# Potential Winnings: $5.09
# Combined Probability: 0.2318
# Combined Odds: 5.75
# Expected Value (EV): $0.33
# Potential Winnings: $5.75
# Combined Probability: 0.2306
# Combined Odds: 5.27
# Expected Value (EV): $0.22
# Potential Winnings: $5.27
# Combined Probability: 0.2306
# Combined Odds: 4.93
# Expected Value (EV): $0.14
# Potential Winnings: $4.93
# Combined Probability: 0.2322
# Combined Odds: 5.15
# Expected Value (EV): $0.20
# Potential Winnings: $5.15
# Combined Probability: 0.2313
# Combined Odds: 5.82
# Expected Value (EV): $0.35
# Potential Winnings: $5.82
# Combined Probability: 0.2310
# Combined Odds: 5.68
# Expected Value (EV): $0.31
# Potential Winnings: $5.68
# Combined Probability: 0.2301
# Combined Odds: 5.34
# Expected Value (EV): $0.23
# Potential Winnings: $5.34
# Combined Probability: 0.2301
# Combined Odds: 4.99
# Expected Value (EV): $0.15
# Potential Winnings: $4.99
# Combined Probability: 0.2269
# Combined Odds: 5.63
# Expected Value (EV): $0.28
# Potential Winnings: $5.63
# Combined Probability: 0.2260
# Combined Odds: 6.37
# Expected Value (EV): $0.44
# Potential Winnings: $6.37
# Combined Probability: 0.2257
# Combined Odds: 6.22
# Expected Value (EV): $0.40
# Potential Winnings: $6.22
# Combined Probability: 0.2249
# Combined Odds: 5.84
# Expected Value (EV): $0.31
# Potential Winnings: $5.84
# Combined Probability: 0.2249
# Combined Odds: 5.46
# Expected Value (EV): $0.23
# Potential Winnings: $5.46
# Combined Probability: 0.2242
# Combined Odds: 6.26
# Expected Value (EV): $0.40
# Potential Winnings: $6.26
# Combined Probability: 0.2239
# Combined Odds: 6.11
# Expected Value (EV): $0.37
# Potential Winnings: $6.11
# Combined Probability: 0.2231
# Combined Odds: 5.74
# Expected Value (EV): $0.28
# Potential Winnings: $5.74
# Combined Probability: 0.2231
# Combined Odds: 6.91
# Expected Value (EV): $0.54
# Potential Winnings: $6.91
# Combined Probability: 0.2222
# Combined Odds: 6.49
# Expected Value (EV): $0.44
# Potential Winnings: $6.49
# Combined Probability: 0.2222
# Combined Odds: 6.07
# Expected Value (EV): $0.35
# Potential Winnings: $6.07
# Combined Probability: 0.2219
# Combined Odds: 6.33
# Expected Value (EV): $0.41
# Potential Winnings: $6.33
# Combined Probability: 0.2219
# Combined Odds: 5.92
# Expected Value (EV): $0.31
# Potential Winnings: $5.92
# Combined Probability: 0.2211
# Combined Odds: 5.56
# Expected Value (EV): $0.23
# Potential Winnings: $5.56
# Combined Probability: 0.2302
# Combined Odds: 4.73
# Expected Value (EV): $0.09
# Potential Winnings: $4.73
# Combined Probability: 0.2293
# Combined Odds: 5.35
# Expected Value (EV): $0.23
# Potential Winnings: $5.35
# Combined Probability: 0.2281
# Combined Odds: 4.90
# Expected Value (EV): $0.12
# Potential Winnings: $4.90
# Combined Probability: 0.2281
# Combined Odds: 4.58
# Expected Value (EV): $0.05
# Potential Winnings: $4.58
# Combined Probability: 0.2249
# Combined Odds: 5.18
# Expected Value (EV): $0.16
# Potential Winnings: $5.18
# Combined Probability: 0.2241
# Combined Odds: 5.85
# Expected Value (EV): $0.31
# Potential Winnings: $5.85
# Combined Probability: 0.2229
# Combined Odds: 5.36
# Expected Value (EV): $0.20
# Potential Winnings: $5.36
# Combined Probability: 0.2229
# Combined Odds: 5.01
# Expected Value (EV): $0.12
# Potential Winnings: $5.01
# Combined Probability: 0.2223
# Combined Odds: 5.75
# Expected Value (EV): $0.28
# Potential Winnings: $5.75
# Combined Probability: 0.2212
# Combined Odds: 5.27
# Expected Value (EV): $0.17
# Potential Winnings: $5.27
# Combined Probability: 0.2203
# Combined Odds: 5.96
# Expected Value (EV): $0.31
# Potential Winnings: $5.96
# Combined Probability: 0.2203
# Combined Odds: 5.57
# Expected Value (EV): $0.23
# Potential Winnings: $5.57
# Combined Probability: 0.2192
# Combined Odds: 5.11
# Expected Value (EV): $0.12
# Potential Winnings: $5.11
# Combined Probability: 0.2218
# Combined Odds: 5.82
# Expected Value (EV): $0.29
# Potential Winnings: $5.82
# Combined Probability: 0.2215
# Combined Odds: 5.68
# Expected Value (EV): $0.26
# Potential Winnings: $5.68
# Combined Probability: 0.2207
# Combined Odds: 5.34
# Expected Value (EV): $0.18
# Potential Winnings: $5.34
# Combined Probability: 0.2207
# Combined Odds: 6.42
# Expected Value (EV): $0.42
# Potential Winnings: $6.42
# Combined Probability: 0.2198
# Combined Odds: 6.03
# Expected Value (EV): $0.33
# Potential Winnings: $6.03
# Combined Probability: 0.2198
# Combined Odds: 5.64
# Expected Value (EV): $0.24
# Potential Winnings: $5.64
# Combined Probability: 0.2195
# Combined Odds: 5.89
# Expected Value (EV): $0.29
# Potential Winnings: $5.89
# Combined Probability: 0.2195
# Combined Odds: 5.51
# Expected Value (EV): $0.21
# Potential Winnings: $5.51
# Combined Probability: 0.2187
# Combined Odds: 5.17
# Expected Value (EV): $0.13
# Potential Winnings: $5.17
# Combined Probability: 0.2168
# Combined Odds: 6.37
# Expected Value (EV): $0.38
# Potential Winnings: $6.37
# Combined Probability: 0.2165
# Combined Odds: 6.22
# Expected Value (EV): $0.35
# Potential Winnings: $6.22
# Combined Probability: 0.2157
# Combined Odds: 5.84
# Expected Value (EV): $0.26
# Potential Winnings: $5.84
# Combined Probability: 0.2157
# Combined Odds: 7.03
# Expected Value (EV): $0.52
# Potential Winnings: $7.03
# Combined Probability: 0.2148
# Combined Odds: 6.60
# Expected Value (EV): $0.42
# Potential Winnings: $6.60
# Combined Probability: 0.2148
# Combined Odds: 6.17
# Expected Value (EV): $0.33
# Potential Winnings: $6.17
# Combined Probability: 0.2145
# Combined Odds: 6.44
# Expected Value (EV): $0.38
# Potential Winnings: $6.44
# Combined Probability: 0.2145
# Combined Odds: 6.02
# Expected Value (EV): $0.29
# Potential Winnings: $6.02
# Combined Probability: 0.2137
# Combined Odds: 5.66
# Expected Value (EV): $0.21
# Potential Winnings: $5.66
# Combined Probability: 0.2139
# Combined Odds: 6.91
# Expected Value (EV): $0.48
# Potential Winnings: $6.91
# Combined Probability: 0.2131
# Combined Odds: 6.49
# Expected Value (EV): $0.38
# Potential Winnings: $6.49
# Combined Probability: 0.2128
# Combined Odds: 6.33
# Expected Value (EV): $0.35
# Potential Winnings: $6.33
# Combined Probability: 0.2120
# Combined Odds: 7.16
# Expected Value (EV): $0.52
# Potential Winnings: $7.16
# Combined Probability: 0.2120
# Combined Odds: 6.69
# Expected Value (EV): $0.42
# Potential Winnings: $6.69
# Combined Probability: 0.2112
# Combined Odds: 6.29
# Expected Value (EV): $0.33
# Potential Winnings: $6.29
# Combined Probability: 0.2109
# Combined Odds: 6.14
# Expected Value (EV): $0.29
# Potential Winnings: $6.14

# %%
candidates_df = pd.DataFrame.from_records(candidates, columns = ["parlay_tag", "props", "COMBINED_PROB", "COMBINED_EV", "TO WIN"]).sort_values(by="COMBINED_EV", ascending=False)
candidates_df.to_csv(f"parlays/{datetime.now().strftime('%Y%m%d%H%M%S')}available_parlays.csv")
