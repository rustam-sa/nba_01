# %%
from data_manager import DataManager

# %%
dm = DataManager()

# %%
# res = dm.pull_players()

# %%
dm.sync_all_team_and_player_records()

# %%
dm.sync_games(season="2024-25", season_type="Regular Season")
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 0      22024  1610612753               ORL  Orlando Magic  0022400352
# 1      22024  1610612753               ORL  Orlando Magic  0022400333
# 2      22024  1610612753               ORL  Orlando Magic  0022400322
# 3      22024  1610612753               ORL  Orlando Magic  0022400053
# 4      22024  1610612753               ORL  Orlando Magic  0022400305
# 5      22024  1610612753               ORL  Orlando Magic  0022400043
# 6      22024  1610612753               ORL  Orlando Magic  0022400289
# 7      22024  1610612753               ORL  Orlando Magic  0022400277
# 8      22024  1610612753               ORL  Orlando Magic  0022400265
# 9      22024  1610612753               ORL  Orlando Magic  0022400263
# 10     22024  1610612753               ORL  Orlando Magic  0022400259
# 11     22024  1610612753               ORL  Orlando Magic  0022400249
# ...
